# %% [markdown]
# # ADNIMERGE data exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading the ADNIMERGE.csv dataset

# %%
adnimerge  = pd.read_csv('/Users/massimilianograssi/Google Drive/Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Study_Info/ADNIMERGE.csv')

# %%
adnimerge.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0     2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1     3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2     3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3     3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4     3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 10    5  011_S_0005      bl    11   ADNI1    ADNI1  2005-09-07    CN  73.7
# ...

# %%
adnimerge2 = adnimerge[adnimerge['VISCODE'].isin(['bl','m06', 'm12', 'm24','m36'])]

# %%
adnimerge2.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 2     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 3     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 4     Male          ...             239.7   22.83  1.09079    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# ...

# %%
adnimerge3 = adnimerge[adnimerge['VISCODE'] == 'bl']

# %%
adnimerge3
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
# 1         3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD
# 5         4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI
# 10        5  011_S_0005      bl    11   ADNI1    ADNI1  2005-09-07    CN
# 15        6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI
# 20        7  022_S_0007      bl    22   ADNI1    ADNI1  2005-10-06    AD
# 22       10  011_S_0010      bl    11   ADNI1    ADNI1  2005-11-10    AD
# 26       14  022_S_0014      bl    22   ADNI1    ADNI1  2005-11-04    CN
# 31       15  100_S_0015      bl   100   ADNI1    ADNI1  2005-10-18    CN
# 34       16  011_S_0016      bl    11   ADNI1    ADNI1  2005-10-13    CN
# 39       21  011_S_0021      bl    11   ADNI1    ADNI1  2005-10-24    CN
# 43       23  011_S_0023      bl    11   ADNI1    ADNI1  2005-11-08    CN
# ...

# %%
adnimerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11488 entries, 0 to 11487
# Columns: 109 entries, RID to update_stamp
# dtypes: float64(86), int64(6), object(17)
# memory usage: 9.6+ MB

# %%
adnimerge.shape
# Out:
# (11488, 109)

# %%
adnimerge.index
# Out:
# RangeIndex(start=0, stop=11488, step=1)

# %%
adnimerge['DX_bl'].unique()
# Out:
# array(['CN', 'AD', 'LMCI', 'SMC', 'EMCI', nan], dtype=object)

# %%
adnimerge.columns.values
# Out:
# array(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT',
#        'EXAMDATE', 'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT',
#        'PTRACCAT', 'PTMARRY', 'APOE4', 'FDG', 'PIB', 'AV45', 'ABETA',
#        'TAU', 'PTAU', 'CDRSB', 'ADAS11', 'ADAS13', 'ADASQ4', 'MMSE',
#        'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_forgetting',
#        'RAVLT_perc_forgetting', 'LDELTOTAL', 'DIGITSCOR', 'TRABSCOR',
#        'FAQ', 'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat',
#        'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal',
#        'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'FLDSTRENG',
#        'FSVERSION', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'DX', 'mPACCdigit',
#        'mPACCtrailsB', 'EXAMDATE_bl', 'CDRSB_bl', 'ADAS11_bl',
#        'ADAS13_bl', 'ADASQ4_bl', 'MMSE_bl', 'RAVLT_immediate_bl',
# ...

# %%
adnimerge.describe() # summary statistics for numerical variables
# Out:
#                 RID          SITE           AGE      PTEDUCAT         APOE4  \
# count  11488.000000  11488.000000  11488.000000  11488.000000  11416.000000
# mean    2190.613162     73.726758     73.990904     15.996344      0.587246
# std     1872.446124    109.696868      6.939489      2.821183      0.669275
# min        2.000000      2.000000     54.400000      4.000000      0.000000
# 25%      572.000000     21.000000     70.000000     14.000000      0.000000
# 50%     1243.000000     41.000000     74.000000     16.000000      0.000000
# 75%     4320.000000    116.000000     78.925000     18.000000      1.000000
# max     6117.000000    941.000000     91.400000     20.000000      2.000000
#
#                FDG         PIB         AV45        ABETA          TAU  \
# count  2977.000000  211.000000  1759.000000  1953.000000  1954.000000
# mean      1.195058    1.808294     1.235786   815.938710   297.059197
# std       0.161594    0.419325     0.231737   358.677395   137.258671
# ...

# %%
adnimerge.describe(include=['O']) # summary statistics for categorical variables
# Out:
#               PTID VISCODE COLPROT ORIGPROT    EXAMDATE  DX_bl PTGENDER  \
# count        11488   11488   11488    11488       11488  11430    11488
# unique        1599      25       4        4        2785      5        2
# top     127_S_0259      bl   ADNI2    ADNI1  2012-02-15   LMCI     Male
# freq            20    1599    5821     6523          17   4422     6604
#
#                PTETHCAT PTRACCAT  PTMARRY      FLDSTRENG  \
# count             11488    11488    11488           6241
# unique                3        7        5              2
# top     Not Hisp/Latino    White  Married  1.5 Tesla MRI
# freq              11097    10701     8876           3676
#
#                                                 FSVERSION    DX EXAMDATE_bl  \
# count                                                6981  7873       11488
# unique                                                  2     3         862
# top     Cross-Sectional FreeSurfer (FreeSurfer Version...   MCI  2006-04-25
# ...

# %%
adnimerge.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 2     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 3     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 4     Male          ...             239.7   22.83  1.09079    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# ...

# %%
df= adnimerge.groupby('VISCODE').count().sort_values(by='DX_bl', ascending=False).loc[['bl', 'm03','m06', 'm12', 'm18', 'm24', 'm30','m36'], 'RID']

# %%
#adnimerge.groupby(['DX', 'VISCODE']).count()
df2 = adnimerge.groupby(['VISCODE', 'DX']).count().loc[['bl', 'm03','m06', 'm12', 'm18', 'm24', 'm30','m36'], 'RID']
df2 = pd.DataFrame(df2)
df2.columns = ['Number of Participants']
df2.unstack(level=1)
# Out:
#         Number of Participants
# DX                          CN Dementia  MCI
# VISCODE
# bl                         453      335  791
# m06                        397      345  689
# m12                        337      364  606
# m18                          7       93  215
# m24                        344      344  418
# m36                        193      193  329

# %%
df3 = adnimerge.groupby(['VISCODE', 'DX_bl']).count().loc[['bl', 'm03','m06', 'm12', 'm18', 'm24', 'm30','m36'], 'RID']
df3 = pd.DataFrame(df3)
df3.columns = ['Number of Participants']
df3.unstack(level=1)
# Out:
#         Number of Participants
# DX_bl                       AD     CN   EMCI   LMCI   SMC
# VISCODE
# bl                       329.0  341.0  257.0  533.0  81.0
# m03                      115.0  126.0  237.0  136.0  47.0
# m06                      298.0  327.0  227.0  510.0  70.0
# m12                      266.0  312.0  233.0  481.0  22.0
# m18                      220.0  307.0  184.0  436.0   NaN
# m24                      177.0  289.0  198.0  410.0  64.0
# m30                       43.0  216.0  110.0  294.0   NaN
# m36                       26.0  191.0  180.0  345.0  10.0

# %%
MCI_bl_AD_m36 = adnimerge[(adnimerge['DX_bl'].isin(['EMCI', "LMCI"])) & (adnimerge['DX'] == 'Dementia') & (adnimerge['VISCODE'] == 'm36')]
MCI_bl_AD_m36


#Method1
#MCI_bl = adnimerge[adnimerge['DX_bl'].isin(['EMCI', "LMCI"])
#DX_Dementia = MCI_bl[MCI_bl['DX'] == 'Dementia']
#Converted_m36 = DX_Dementia[DX_Dementia['VISCODE'] == 'm36']
#Converted_m36

#Method2
#np.unique(np.array(new['RID'].loc[new['DX'] == 'Dementia']))

#Method3
#new = adnimerge[adnimerge['DX_bl'] == 'CN']
#new2 = new.loc[new['VISCODE'] == 'm36', ['RID', 'DX_bl', 'DX']]
#new2
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 74      42  023_S_0042     m36    23   ADNI1    ADNI1  2008-12-05  LMCI  72.8
# 248     98  067_S_0098     m36    67   ADNI1    ADNI1  2009-04-02  LMCI  84.4
# 254    101  007_S_0101     m36     7   ADNI1    ADNI1  2008-12-23  LMCI  73.6
# 277    108  123_S_0108     m36   123   ADNI1    ADNI1  2009-02-12  LMCI  78.2
# 332    126  023_S_0126     m36    23   ADNI1    ADNI1  2009-03-03  LMCI  77.5
# 340    128  007_S_0128     m36     7   ADNI1    ADNI1  2009-02-12  LMCI  64.1
# 361    141  021_S_0141     m36    21   ADNI1    ADNI1  2009-02-24  LMCI  81.1
# 443    179  027_S_0179     m36    27   ADNI1    ADNI1  2009-03-10  LMCI  80.9
# 477    195  136_S_0195     m36   136   ADNI1    ADNI1  2009-04-07  LMCI  79.6
# 493    204  035_S_0204     m36    35   ADNI1    ADNI1  2009-03-05  LMCI  71.1
# 510    214  032_S_0214     m36    32   ADNI1    ADNI1  2009-02-23  LMCI  65.1
# ...

# %%
adnimerge['VISCODE'].value_counts()
# Out:
# bl      1599
# m06     1432
# m12     1314
# m18     1147
# m24     1138
# m36      752
# m30      663
# m03      661
# m48      581
# m60      355
# m72      305
# m42      279
# m66      198
# m78      195
# m84      187
# m54      185
# m96      142
# m90      119
# m108     106
# m120      75
# m132      37
# m144       8
# m102       5
# m126       4
# m114       1
# Name: VISCODE, dtype: int64

# %%
adnimerge3['DX'].value_counts()
# Out:
# MCI         791
# CN          453
# Dementia    335
# Name: DX, dtype: int64

# %%
#adnimerge[adnimerge['VISCODE'] == 'bl'].groupby('DX').count()['RID']
adnimerge[adnimerge['VISCODE'] == 'bl']['DX'].value_counts()
# Out:
# MCI         791
# CN          453
# Dementia    335
# Name: DX, dtype: int64

# %%
bl = adnimerge[adnimerge['VISCODE'] == 'bl'].groupby('DX').count()['RID']
bl
# Out:
# DX
# CN          453
# Dementia    335
# MCI         791
# Name: RID, dtype: int64

# %%
m06 = adnimerge[adnimerge['VISCODE'] == 'm06'].groupby('DX').count()['RID']
m06
# Out:
# DX
# CN          397
# Dementia    345
# MCI         689
# Name: RID, dtype: int64

# %%
m12 = adnimerge[adnimerge['VISCODE'] == 'm12'].groupby('DX').count()['RID']
m12
# Out:
# DX
# CN          337
# Dementia    364
# MCI         606
# Name: RID, dtype: int64

# %%
m18 = adnimerge[adnimerge['VISCODE'] == 'm18'].groupby('DX').count()['RID']
m18
# Out:
# DX
# CN            7
# Dementia     93
# MCI         215
# Name: RID, dtype: int64

# %%
m24 = adnimerge[adnimerge['VISCODE'] == 'm24'].groupby('DX').count()['RID']
m24
# Out:
# DX
# CN          344
# Dementia    344
# MCI         418
# Name: RID, dtype: int64

# %%
m36 = adnimerge[adnimerge['VISCODE'] == 'm36'].groupby('DX').count()['RID']
m36
# Out:
# DX
# CN          193
# Dementia    193
# MCI         329
# Name: RID, dtype: int64

# %%
objects = [bl, m06, m12, m18, m24, m36]
overview_DX = pd.concat(objects, axis=1)
overview_DX.columns = ['bl', 'm06', 'm12', 'm18', 'm24', 'm36']
overview_DX
# Out:
#            bl  m06  m12  m18  m24  m36
# DX
# CN        453  397  337    7  344  193
# Dementia  335  345  364   93  344  193
# MCI       791  689  606  215  418  329

# %% [markdown]
# ## Visualizing Distributions

# %%
adnimerge.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 2     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 3     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 4     Male          ...             239.7   22.83  1.09079    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# ...

# %%
# plt.style.use('seaborn-white')

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 10))


axs[0, 0].hist(adnimerge3['COLPROT'])
axs[0, 0].set_xlabel('Study')
axs[0, 0].set_ylabel('frequency')

axs[0, 1].hist(adnimerge3['DX'].dropna())
axs[0, 1].set_xlabel('Diagnosis')
axs[0, 1].set_ylabel('frequency')

axs[1, 0].hist(adnimerge3['AGE'], ec='black')
axs[1, 0].set_xlabel('Age')
axs[1, 0].set_ylabel('frequency')

axs[2, 1].hist(adnimerge3['ABETA'].dropna(), ec='black')
axs[2, 1].set_xlabel('ABETA')
axs[2, 1].set_ylabel('frequency')

axs[2, 0].hist(adnimerge3['TAU'].dropna(), ec='black')
axs[2, 0].set_xlabel('Tau')
axs[2, 0].set_ylabel('frequency')

axs[1, 1].hist(adnimerge3['MMSE'].dropna(), ec='black')
axs[1, 1].set_xlabel('MMSE')
axs[1, 1].set_ylabel('frequency')


#sns.boxplot(x="DX_bl", y="ABETA", data=adnimerge, ax=axs[2,0])
#sns.boxplot(x="DX_bl", y="MMSE", data=adnimerge, ax=axs[2,1])
# Out:
# Text(0,0.5,'frequency')

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

sns.stripplot(x="VISCODE", y="MMSE", hue="DX", data=adnimerge2, ax=axs[0])
sns.swarmplot(x="VISCODE", y="ABETA", hue="DX", data=adnimerge2, ax=axs[1])

# %%
plt.figure(figsize=(12,6))
sns.stripplot(x="VISCODE", y="MMSE", hue="DX", data=adnimerge2)

#sns.swarmplot(x="VISCODE", y="MMSE", hue="DX", data=adnimerge2)

#plt.figure()
#plt.scatter(adnimerge2['VISCODE'].astype(str), adnimerge2['MMSE'])
#plt.xticks(range(36),['bl','','',''])
#plt.xlim(0,10)

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(x="VISCODE", y="ABETA", hue="DX", data=adnimerge2)

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 12))

sns.boxplot(x="DX_bl", y="ABETA", data=adnimerge3, ax=axs[0,1])
sns.boxplot(x="DX_bl", y="MMSE", data=adnimerge3, ax=axs[1,0])
sns.boxplot(x="DX_bl", y="AGE", data=adnimerge3, ax=axs[0,0])
sns.boxplot(x="DX_bl", y="TAU", data=adnimerge3, ax=axs[2,0])
sns.boxplot(x="DX_bl", y="PTAU", data=adnimerge3, ax=axs[2,1])
sns.boxplot(x="DX_bl", y="CDRSB", data=adnimerge3, ax=axs[1,1])

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX_bl", y="MMSE", data=adnimerge2)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX_bl", y="AGE", data=adnimerge2)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX_bl", y="TAU", data=adnimerge2)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX_bl", y="PTAU", data=adnimerge2)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX_bl", y="", data=adnimerge2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-a96058a5ddd4> in <module>()
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.boxplot(x="DX_bl", data=adnimerge2)
#
# ~/anaconda/envs/Py35/lib/python3.5/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~/anaconda/envs/Py35/lib/python3.5/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
#     545         self.annotate_axes(ax)
#     546         if self.orient == "h":
#
# ...

# %%
plt.figure(figsize=(25,6))
sns.heatmap(adnimerge2.isnull(),yticklabels=False,cbar=False, cmap='viridis')

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

sns.set_style('whitegrid')
sns.set_color_codes("muted")

sns.countplot(x='COLPROT',hue='PTGENDER',data=adnimerge3, color='#1f77b4', ax=axs[0,0])
sns.countplot(x='VISCODE', hue='DX',data=adnimerge2, color='#1f77b4', ax=axs[1,0])
sns.countplot(x='DX', hue='PTGENDER',data=adnimerge3, color='#1f77b4', ax=axs[0,1])
sns.countplot(x='APOE4', hue='DX',data=adnimerge3, color='#1f77b4', ax=axs[1,1])

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x="DX", y="ABETA", hue='APOE4', data=adnimerge2)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="DX", y="ABETA", hue='APOE4', data=adnimerge3)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="DX_bl", y="Ventricles", hue='APOE4', data=adnimerge)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="DX_bl", y="ADAS13", hue='APOE4', data=adnimerge)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="DX_bl", y="ADAS11", hue='APOE4', data=adnimerge)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="DX_bl", y="MMSE", hue='APOE4', data=adnimerge)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="DX_bl", y="Ventricles", data=adnimerge)

# %%
 #adnimerge[(adnimerge['DX_bl'] == 'EMCI') & (adnimerge['DX'] == 'Dementia') & (adnimerge['VISCODE'] == 'm36')]

def converter(RID):
    adnimerge_converters = 0
    for DX_bl, DX, VISCODE in zip(adnimerge[['DX_bl', 'DX', 'VISCODE']]):
        if DX_bl == 'EMCI' and DX == 'Dementia' and VISCODE == 'm36':
            adnimerge_converters = adnimergeconverters + 1
        else:
            adnimerge_converters = adnimerge_converters
