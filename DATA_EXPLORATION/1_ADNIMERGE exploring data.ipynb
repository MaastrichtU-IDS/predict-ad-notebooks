# %% [markdown]
# # ADNIMERGE data exploration
# This notebook is to serve as to get familiar with the largest ADNI dataset, the ADNIMERGE file;
# provide some summary statistics, get insights into the disease populations, distributions, exploratory data analysis and correlations (still to be added).

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the ADNIMERGE.csv dataset
# The ADNIMERGE dataset can be found in the folder DATA_15_12_2017/Study_info. The data in this folder are limited to study info, clinical, sociodemographic and neuropsychological data. Imaging and genetics data are still at our availability, but not yet downloaded. The ADNIMERGE dataset is basically one large dataset containing the most important features of the ADNI study, and most/all can also be found in the separate datasets in the DATA folder. In case you would like to know what all the abbreviations are, you can find all study codes in the so-called 'dictionary files, and the file ADNIMERGE_DICT in the Study_info folder contains specifically the codes for the ADNIMERGE data (see below also).
# More info on the ADNI study in general (centers included, cohorts-ADNI1, ADNIGO, ADNI2, ADNI3, study design etc.) can be found on the website: http://adni.loni.usc.edu/

# %%
data = pd.read_csv('Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Study_Info/ADNIMERGE.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4c6d6750e4bd> in <module>()
# ----> 1 data = pd.read_csv('Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Study_Info/ADNIMERGE.csv')
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     703                     skip_blank_lines=skip_blank_lines)
#     704
# --> 705         return _read(filepath_or_buffer, kwds)
#     706
#     707     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     443
#     444     # Create the parser.
# --> 445     parser = TextFileReader(filepath_or_buffer, **kwds)
#     446
#     447     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options['has_index_names'] = kwds['has_index_names']
#     813
# --> 814         self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043     def _make_engine(self, engine='c'):
#    1044         if engine == 'c':
# -> 1045             self._engine = CParserWrapper(self.f, **self.options)
#    1046         else:
#    1047             if engine == 'python':
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1682         kwds['allow_leading_cols'] = self.index_col is not False
#    1683
# -> 1684         self._reader = parsers.TextReader(src, **kwds)
#    1685
#    1686         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Study_Info/ADNIMERGE.csv' does not exist

# %%
data.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 2     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 3     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 4     Male          ...             239.7   22.83  1.09079    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# 0  0.000000   0.00000      0   0  2017-12-08 23:40:58.0
# 1  0.000000   0.00000      0   0  2017-12-08 23:40:58.0
# 2  0.498289   5.96721      6   6  2017-12-08 23:40:58.0
# 3  0.999316  11.96720     12  12  2017-12-08 23:40:58.0
# 4  1.998630  23.93440     24  24  2017-12-08 23:40:58.0
#
# [5 rows x 109 columns]

# %% [markdown]
# ### Subject Selection for ADNI
# The subjects for the study were classified as
# normal controls, subjects with MCI, or subjects with mild AD.
# The criteria for classification of the subjects were as follows.
# With respect to memory complaints, the normal subjects had
# none, while the subjects with MCI and subjects with AD both
# had to have complaints. On the Mini-Mental State Examination
# (MMSE), the range for the normal subjects and subjects with
# MCI was 24 –30, and for AD 20 –26; all are inclusive. The CDR
# score for normal subjects was 0 and for subjects with MCI was
# 0.5 with a mandatory requirement of the memory box score
# being 0.5 or greater, and the rating for subjects with AD was 0.5
# or 1. For the memory criterion, delayed recall of 1 paragraph
# from the Logical Memory II subscale of the Wechsler Memory
# Scale–Revised (maximum score of 25)12 was used with cutoff
# scores as follows based on education: normal subjects 9 for 16
# years of education, 5 for 8 –15 years of education, and 3 for
# 0 –7 years of education. For subjects with MCI and subjects with
# AD, these scores were 8 for 16 years of education, 4 for
# 8 –15 years of education, and 2 for 0 –7 years of education.
# In addition, the normal control subjects were to be matched to
# the other subjects in age and could not have any significant impairment
# in cognitive functions or activities of daily living. The subjects
# with MCI had to be largely intact with regard to general cognition
# and functional performance, and could not qualify for the diagnosis
# of dementia. The subjects with AD had mild AD and had to meet
# the National Institute of Neurological and Communicative Disorders
# and Stroke–Alzheimer’s Disease and Related Disorders Association
# criteria for probable AD.

# %% [markdown]
# ### Loading the data_dictionary for ADNIMERGE

# %%
ADNIMERGE_dictionary = pd.read_csv('Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Study_Info/ADNIMERGE_DICT.csv')

# %%
ADNIMERGE_dictionary[['FLDNAME', 'TBLNAME', 'CRFNAME', 'TEXT']]
# Out:
#                       FLDNAME    TBLNAME  \
# 0                         RID  ADNIMERGE
# 1                        PTID  ADNIMERGE
# 2                       ABETA  ADNIMERGE
# 3                     VISCODE  ADNIMERGE
# 4                        SITE  ADNIMERGE
# 5                     COLPROT  ADNIMERGE
# 6                    ORIGPROT  ADNIMERGE
# 7                    EXAMDATE  ADNIMERGE
# 8                       DX_bl  ADNIMERGE
# 9                         AGE  ADNIMERGE
# 10                   PTGENDER  ADNIMERGE
# 11                   PTEDUCAT  ADNIMERGE
# 12                   PTETHCAT  ADNIMERGE
# 13                   PTRACCAT  ADNIMERGE
# 14                    PTMARRY  ADNIMERGE
# 15                      APOE4  ADNIMERGE
# 16                        FDG  ADNIMERGE
# 17                        PIB  ADNIMERGE
# 18                       AV45  ADNIMERGE
# 19                      CDRSB  ADNIMERGE
# 20                     ADAS11  ADNIMERGE
# 21                     ADAS13  ADNIMERGE
# 22                       MMSE  ADNIMERGE
# 23                      RAVLT  ADNIMERGE
# 24            RAVLT_immediate  ADNIMERGE
# 25                        FAQ  ADNIMERGE
# 26                       MOCA  ADNIMERGE
# 27                  EcogPtMem  ADNIMERGE
# 28                 EcogPtLang  ADNIMERGE
# 29              EcogPtVisspat  ADNIMERGE
# ..                        ...        ...
# 83             EcogSPTotal_bl  ADNIMERGE
# 84                   ABETA_bl  ADNIMERGE
# 85                     FDG_bl  ADNIMERGE
# 86                     PIB_bl  ADNIMERGE
# 87                    AV45_bl  ADNIMERGE
# 88                   Years_bl  ADNIMERGE
# 89                   Month_bl  ADNIMERGE
# 90                      Month  ADNIMERGE
# 91                          M  ADNIMERGE
# 92                        TAU  ADNIMERGE
# 93                       PTAU  ADNIMERGE
# 94                     ADASQ4  ADNIMERGE
# 95             RAVLT_learning  ADNIMERGE
# 96           RAVLT_forgetting  ADNIMERGE
# 97      RAVLT_perc_forgetting  ADNIMERGE
# 98                  LDELTOTAL  ADNIMERGE
# 99                  DIGITSCOR  ADNIMERGE
# 100                  TRABSCOR  ADNIMERGE
# 101              mPACCtrailsB  ADNIMERGE
# 102                 ADASQ4_bl  ADNIMERGE
# 103         RAVLT_learning_bl  ADNIMERGE
# 104       RAVLT_forgetting_bl  ADNIMERGE
# 105  RAVLT_perc_forgetting_bl  ADNIMERGE
# 106              LDELTOTAL_bl  ADNIMERGE
# 107              DIGITSCOR_bl  ADNIMERGE
# 108               TRABSCOR_bl  ADNIMERGE
# 109             mPACCdigit_bl  ADNIMERGE
# 110           mPACCtrailsB_bl  ADNIMERGE
# 111              FLDSTRENG_bl  ADNIMERGE
# 112              FSVERSION_bl  ADNIMERGE
#
#                                       CRFNAME  \
# 0    Key variables merged into one data table
# 1    Key variables merged into one data table
# 2    Key variables merged into one data table
# 3    Key variables merged into one data table
# 4    Key variables merged into one data table
# 5    Key variables merged into one data table
# 6    Key variables merged into one data table
# 7    Key variables merged into one data table
# 8    Key variables merged into one data table
# 9    Key variables merged into one data table
# 10   Key variables merged into one data table
# 11   Key variables merged into one data table
# 12   Key variables merged into one data table
# 13   Key variables merged into one data table
# 14   Key variables merged into one data table
# 15   Key variables merged into one data table
# 16   Key variables merged into one data table
# 17   Key variables merged into one data table
# 18   Key variables merged into one data table
# 19   Key variables merged into one data table
# 20   Key variables merged into one data table
# 21   Key variables merged into one data table
# 22   Key variables merged into one data table
# 23      Key ADNI tables merged into one table
# 24   Key variables merged into one data table
# 25   Key variables merged into one data table
# 26   Key variables merged into one data table
# 27   Key variables merged into one data table
# 28   Key variables merged into one data table
# 29   Key variables merged into one data table
# ..                                        ...
# 83   Key variables merged into one data table
# 84   Key variables merged into one data table
# 85   Key variables merged into one data table
# 86   Key variables merged into one data table
# 87   Key variables merged into one data table
# 88   Key variables merged into one data table
# 89   Key variables merged into one data table
# 90   Key variables merged into one data table
# 91   Key variables merged into one data table
# 92   Key variables merged into one data table
# 93   Key variables merged into one data table
# 94   Key variables merged into one data table
# 95   Key variables merged into one data table
# 96   Key variables merged into one data table
# 97   Key variables merged into one data table
# 98   Key variables merged into one data table
# 99   Key variables merged into one data table
# 100  Key variables merged into one data table
# 101  Key variables merged into one data table
# 102  Key variables merged into one data table
# 103  Key variables merged into one data table
# 104  Key variables merged into one data table
# 105  Key variables merged into one data table
# 106  Key variables merged into one data table
# 107  Key variables merged into one data table
# 108  Key variables merged into one data table
# 109  Key variables merged into one data table
# 110  Key variables merged into one data table
# 111  Key variables merged into one data table
# 112  Key variables merged into one data table
#
#                                                   TEXT
# 0                                Participant roster ID
# 1                              Original study protocol
# 2                                            CSF ABETA
# 3                                           Visit code
# 4                                                 Site
# 5                    Study protocol of data collection
# 6                              Original study protocol
# 7                                                 Date
# 8                                          Baseline Dx
# 9                                                  Age
# 10                                                 Sex
# 11                                           Education
# 12                                           Ethnicity
# 13                                                Race
# 14                                             Marital
# 15                                               ApoE4
# 16   Average FDG-PET of angular, temporal, and post...
# 17   Average PIB SUVR of frontal cortex, anterior c...
# 18   Reference region - florbetapir mean of whole c...
# 19                                              CDR-SB
# 20                                             ADAS 11
# 21                                             ADAS 13
# 22                                                MMSE
# 23                                  RAVLT (forgetting)
# 24                   RAVLT Immediate (sum of 5 trials)
# 25                                                 FAQ
# 26                                                MOCA
# 27                                       Pt ECog - Mem
# 28                                      Pt ECog - Lang
# 29                                  Pt ECog - Vis/Spat
# ..                                                 ...
# 83                                     SP ECog - Total
# 84                                           CSF ABETA
# 85   Average FDG-PET of angular, temporal, and post...
# 86   Average PIB SUVR of frontal cortex, anterior c...
# 87   Reference region - florbetapir mean of whole c...
# 88                                                 NaN
# 89                                                 NaN
# 90                               Months since baseline
# 91                                Month since baseline
# 92                                             CSF TAU
# 93                                            CSF PTAU
# 94                            ADAS Delayed Word Recall
# 95                  RAVLT Learning (trial 5 - trial 1)
# 96                RAVLT Forgetting (trial 5 - delayed)
# 97                            RAVLT Percent Forgetting
# 98                     Logical Memory - Delayed Recall
# 99                           Digit Symbol Substitution
# 100                                           Trails B
# 101  ADNI modified Preclinical Alzheimer's Cognitiv...
# 102                           ADAS Delayed Word Recall
# 103                 RAVLT Learning (trial 5 - trial 1)
# 104               RAVLT Forgetting (trial 5 - delayed)
# 105                           RAVLT Percent Forgetting
# 106                    Logical Memory - Delayed Recall
# 107                          Digit Symbol Substitution
# 108                                           Trails B
# 109  ADNI modified Preclinical Alzheimer's Cognitiv...
# 110  ADNI modified Preclinical Alzheimer's Cognitiv...
# 111                                 MRI Field Strength
# 112                        FreeSurfer Software Version
#
# [113 rows x 4 columns]

# %% [markdown]
# ### Loading the orginal ADAS sub and total scores from neuropsychological assessments
# Check whether TOTAL11 and TOTALMOD are equal values as ADAS11 and ADAS13 in ADNIMERGE table. Sometimes different names are being used in different datasets of the ADNI study, so here I just wanted to check whether the ADAS11 and ADAS13 scores in ADNIMERGE are the same to the TOTAL11 and TOTAL13 scores, which are being used in the ADASSCORES dataset in Assessments folder. ADAS = Alzheimer's disease Assessment Scale, scale for cognitive functioning, the higher the score, the better. Normal individuals have a score of 30, MCI patients between 24-30 and Alzheimer patients between 20-26.

# %%
ADAS_sub_total = pd.read_csv('Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Assessments/ADASSCORES.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c821b7912067> in <module>()
# ----> 1 ADAS_sub_total = pd.read_csv('Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Assessments/ADASSCORES.csv')
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     703                     skip_blank_lines=skip_blank_lines)
#     704
# --> 705         return _read(filepath_or_buffer, kwds)
#     706
#     707     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     443
#     444     # Create the parser.
# --> 445     parser = TextFileReader(filepath_or_buffer, **kwds)
#     446
#     447     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options['has_index_names'] = kwds['has_index_names']
#     813
# --> 814         self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043     def _make_engine(self, engine='c'):
#    1044         if engine == 'c':
# -> 1045             self._engine = CParserWrapper(self.f, **self.options)
#    1046         else:
#    1047             if engine == 'python':
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1682         kwds['allow_leading_cols'] = self.index_col is not False
#    1683
# -> 1684         self._reader = parsers.TextReader(src, **kwds)
#    1685
#    1686         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Joint_projects_DS_Massi/1_ADNI_MCI_to_AD/DATA_15_12_2017/Assessments/ADASSCORES.csv' does not exist

# %%
ADAS_sub_total.head()

# %%
data_1412_ADNIMERGE = data[data['RID'] == 1412][['VISCODE','ADAS11', 'ADAS13', 'DX_bl']]

# %%
data_1412_ADNIMERGE
# Out:
#      VISCODE  ADAS11  ADAS13 DX_bl
# 2805      bl   13.67   17.67  LMCI
# 2806     m06   10.33   19.33  LMCI
# 2807     m12   10.33   16.33  LMCI

# %%
data_1412_ADASSCORES = ADAS_sub_total[ADAS_sub_total['RID'] == 1412][['VISCODE', 'TOTAL11', 'TOTALMOD']]

# %%
data_1412_ADASSCORES.sort_values(by='VISCODE')
# Out:
#   VISCODE  TOTAL11  TOTALMOD
# 2      bl    13.67     17.67
# 1     m06    10.33     19.33
# 0     m12    10.33     16.33

# %% [markdown]
# ## Exploring the ADNIMERGE dataset

# %%
data.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 2     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 3     Male          ...             239.7   22.83  1.09079    NaN      NaN
# 4     Male          ...             239.7   22.83  1.09079    NaN      NaN
#
#    Years_bl  Month_bl  Month   M           update_stamp
# 0  0.000000   0.00000      0   0  2017-12-08 23:40:58.0
# 1  0.000000   0.00000      0   0  2017-12-08 23:40:58.0
# 2  0.498289   5.96721      6   6  2017-12-08 23:40:58.0
# 3  0.999316  11.96720     12  12  2017-12-08 23:40:58.0
# 4  1.998630  23.93440     24  24  2017-12-08 23:40:58.0
#
# [5 rows x 109 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11488 entries, 0 to 11487
# Columns: 109 entries, RID to update_stamp
# dtypes: float64(86), int64(6), object(17)
# memory usage: 9.6+ MB

# %% [markdown]
# ### Columns in ADNIMERGE

# %%
print(data.columns.values)
# Out:
# ['RID' 'PTID' 'VISCODE' 'SITE' 'COLPROT' 'ORIGPROT' 'EXAMDATE' 'DX_bl'
#  'AGE' 'PTGENDER' 'PTEDUCAT' 'PTETHCAT' 'PTRACCAT' 'PTMARRY' 'APOE4' 'FDG'
#  'PIB' 'AV45' 'ABETA' 'TAU' 'PTAU' 'CDRSB' 'ADAS11' 'ADAS13' 'ADASQ4'
#  'MMSE' 'RAVLT_immediate' 'RAVLT_learning' 'RAVLT_forgetting'
#  'RAVLT_perc_forgetting' 'LDELTOTAL' 'DIGITSCOR' 'TRABSCOR' 'FAQ' 'MOCA'
#  'EcogPtMem' 'EcogPtLang' 'EcogPtVisspat' 'EcogPtPlan' 'EcogPtOrgan'
#  'EcogPtDivatt' 'EcogPtTotal' 'EcogSPMem' 'EcogSPLang' 'EcogSPVisspat'
#  'EcogSPPlan' 'EcogSPOrgan' 'EcogSPDivatt' 'EcogSPTotal' 'FLDSTRENG'
#  'FSVERSION' 'Ventricles' 'Hippocampus' 'WholeBrain' 'Entorhinal'
#  'Fusiform' 'MidTemp' 'ICV' 'DX' 'mPACCdigit' 'mPACCtrailsB' 'EXAMDATE_bl'
#  'CDRSB_bl' 'ADAS11_bl' 'ADAS13_bl' 'ADASQ4_bl' 'MMSE_bl'
#  'RAVLT_immediate_bl' 'RAVLT_learning_bl' 'RAVLT_forgetting_bl'
#  'RAVLT_perc_forgetting_bl' 'FAQ_bl' 'mPACCdigit_bl' 'mPACCtrailsB_bl'
#  'FLDSTRENG_bl' 'FSVERSION_bl' 'Ventricles_bl' 'Hippocampus_bl'
#  'WholeBrain_bl' 'Entorhinal_bl' 'Fusiform_bl' 'MidTemp_bl' 'ICV_bl'
#  'MOCA_bl' 'EcogPtMem_bl' 'EcogPtLang_bl' 'EcogPtVisspat_bl'
#  'EcogPtPlan_bl' 'EcogPtOrgan_bl' 'EcogPtDivatt_bl' 'EcogPtTotal_bl'
#  'EcogSPMem_bl' 'EcogSPLang_bl' 'EcogSPVisspat_bl' 'EcogSPPlan_bl'
#  'EcogSPOrgan_bl' 'EcogSPDivatt_bl' 'EcogSPTotal_bl' 'ABETA_bl' 'TAU_bl'
#  'PTAU_bl' 'FDG_bl' 'PIB_bl' 'AV45_bl' 'Years_bl' 'Month_bl' 'Month' 'M'
#  'update_stamp']

# %% [markdown]
# ### Summary Statistics

# %%
data.describe() #describe for numerical variables
# Out:
#                 RID          SITE           AGE      PTEDUCAT         APOE4  \
# count  11488.000000  11488.000000  11488.000000  11488.000000  11416.000000
# mean    2190.613162     73.726758     73.990904     15.996344      0.587246
# std     1872.446124    109.696868      6.939489      2.821183      0.669275
# min        2.000000      2.000000     54.400000      4.000000      0.000000
# 25%      572.000000     21.000000     70.000000     14.000000      0.000000
# 50%     1243.000000     41.000000     74.000000     16.000000      0.000000
# 75%     4320.000000    116.000000     78.925000     18.000000      1.000000
# max     6117.000000    941.000000     91.400000     20.000000      2.000000
#
#                FDG         PIB         AV45        ABETA          TAU  \
# count  2977.000000  211.000000  1759.000000  1953.000000  1954.000000
# mean      1.195058    1.808294     1.235786   815.938710   297.059197
# std       0.161594    0.419325     0.231737   358.677395   137.258671
# min       0.636804    1.095000     0.814555   203.000000    88.690000
# 25%       1.097510    1.395000     1.031510   540.200000   195.325000
# 50%       1.205180    1.882500     1.205920   730.900000   266.850000
# 75%       1.303010    2.132500     1.409845  1038.000000   369.650000
# max       1.707170    2.927500     2.669210  1697.000000   915.800000
#
#            ...         ABETA_bl       TAU_bl      PTAU_bl       FDG_bl  \
# count      ...       7355.00000  7355.000000  7355.000000  8050.000000
# mean       ...        868.77743   281.834397    27.457534     1.235431
# std        ...        369.29427   129.965956    14.446639     0.146741
# min        ...        203.00000    88.690000     8.210000     0.697264
# 25%        ...        576.40000   185.700000    16.480000     1.146280
# 50%        ...        781.00000   250.200000    23.980000     1.242320
# 75%        ...       1124.00000   349.200000    34.830000     1.331405
# max        ...       1697.00000   851.800000   103.000000     1.707170
#
#            PIB_bl      AV45_bl      Years_bl      Month_bl         Month  \
# count  148.000000  4860.000000  11488.000000  11488.000000  11488.000000
# mean     1.589713     1.241582      2.276905     27.266864     27.183583
# std      0.305744     0.224429      2.305529     27.609655     27.571148
# min      1.155000     0.838537      0.000000      0.000000      0.000000
# 25%      1.360000     1.043500      0.498289      5.967210      6.000000
# 50%      1.490000     1.214780      1.524980     18.262300     18.000000
# 75%      1.835000     1.414190      3.146475     37.680300     36.000000
# max      2.282500     2.025560     12.109500    145.016000    144.000000
#
#                   M
# count  11488.000000
# mean      26.989815
# std       27.365763
# min        0.000000
# 25%        6.000000
# 50%       18.000000
# 75%       36.000000
# max      144.000000
#
# [8 rows x 92 columns]

# %%
data.describe(include=['O'])  #describe for categorical variables
# Out:
#               PTID VISCODE COLPROT ORIGPROT    EXAMDATE  DX_bl PTGENDER  \
# count        11488   11488   11488    11488       11488  11430    11488
# unique        1599      25       4        4        2785      5        2
# top     127_S_0112      bl   ADNI2    ADNI1  2012-02-15   LMCI     Male
# freq            20    1599    5821     6523          17   4422     6604
#
#                PTETHCAT PTRACCAT  PTMARRY      FLDSTRENG  \
# count             11488    11488    11488           6241
# unique                3        7        5              2
# top     Not Hisp/Latino    White  Married  1.5 Tesla MRI
# freq              11097    10701     8876           3676
#
#                                                 FSVERSION    DX EXAMDATE_bl  \
# count                                                6981  7873       11488
# unique                                                  2     3         862
# top     Cross-Sectional FreeSurfer (FreeSurfer Version...   MCI  2006-04-25
# freq                                                 3695  3574          86
#
#          FLDSTRENG_bl                                       FSVERSION_bl  \
# count           10158                                              11346
# unique              2                                                  2
# top     1.5 Tesla MRI  Cross-Sectional FreeSurfer (FreeSurfer Version...
# freq             6501                                               6514
#
#                  update_stamp
# count                   11488
# unique                     24
# top     2017-12-08 23:41:02.0
# freq                      917

# %% [markdown]
# ### Exploring relationships

# %%
data[['PTGENDER', 'APOE4']].sort_values(by='PTGENDER')
# Out:
#       PTGENDER  APOE4
# 3643    Female    0.0
# 9452    Female    1.0
# 9453    Female    1.0
# 9454    Female    1.0
# 7966    Female    0.0
# 7965    Female    0.0
# 3500    Female    2.0
# 3499    Female    2.0
# 9451    Female    1.0
# 3498    Female    2.0
# 3496    Female    2.0
# 3495    Female    2.0
# 3494    Female    1.0
# 3493    Female    1.0
# 3492    Female    1.0
# 3491    Female    1.0
# 3490    Female    1.0
# 3497    Female    2.0
# 7964    Female    0.0
# 9450    Female    1.0
# 9448    Female    1.0
# 7976    Female    1.0
# 7975    Female    1.0
# 7974    Female    0.0
# 7973    Female    0.0
# 7972    Female    0.0
# 9436    Female    2.0
# 9437    Female    2.0
# 9449    Female    1.0
# 9438    Female    2.0
# ...        ...    ...
# 4926      Male    0.0
# 4924      Male    0.0
# 4923      Male    0.0
# 4922      Male    1.0
# 4921      Male    0.0
# 4920      Male    0.0
# 4919      Male    0.0
# 4917      Male    0.0
# 4915      Male    0.0
# 4914      Male    0.0
# 4912      Male    0.0
# 4910      Male    0.0
# 4907      Male    0.0
# 4906      Male    1.0
# 4905      Male    1.0
# 4904      Male    1.0
# 4901      Male    1.0
# 4900      Male    0.0
# 4899      Male    1.0
# 4898      Male    0.0
# 4896      Male    1.0
# 4895      Male    1.0
# 4894      Male    1.0
# 4893      Male    1.0
# 4892      Male    1.0
# 4891      Male    0.0
# 4890      Male    0.0
# 4889      Male    0.0
# 4886      Male    0.0
# 11487     Male    0.0
#
# [11488 rows x 2 columns]

# %%
data[['PTGENDER', 'APOE4']].groupby(['PTGENDER'], as_index=False).mean()
# Out:
#   PTGENDER     APOE4
# 0   Female  0.571310
# 1     Male  0.598966

# %%
df_age_abeta = data[['AGE', 'ABETA']].sort_values(by='ABETA')

# %%
df_age_abeta.head()
# Out:
#        AGE  ABETA
# 7411  71.7  203.0
# 259   87.3  210.9
# 1366  83.1  212.3
# 6380  74.6  212.3
# 1317  68.4  213.1

# %%
data['DX_bl'].unique()
# Out:
# array(['CN', 'AD', 'LMCI', 'SMC', 'EMCI', nan], dtype=object)

# %%
df_cn = data[data['DX_bl'] =='CN']#[['AgeBand','DX_bl']]
df_ad = data[data['DX_bl'] =='AD']#[['AgeBand','DX_bl']]

# %%
data[(data['AGE'] > 60) & (data['DX_bl'] =='CN')]
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
#
# 2    (72.9, 82.15]  645
# 3    (82.15, 91.4]  285

# %%
df_ad[['AgeBand', 'MMSE', 'CDRSB', 'ADAS13', "ADAS11"]].groupby('AgeBand', as_index=False).mean()
# Out:
#            AgeBand       MMSE     CDRSB     ADAS13     ADAS11
# 0  (54.363, 63.65]  20.808989  5.544444  34.499881  23.494270
# 1    (63.65, 72.9]  21.293578  5.292945  33.404148  23.104303
# 2    (72.9, 82.15]  21.794989  5.567873  32.572233  21.951304
# 3    (82.15, 91.4]  21.726829  6.174020  33.233990  22.671569

# %%
#ageCat= []
#for item in data['AGE']:
#    if item <= 65:
#        ageCat.append(0)
#   elif (item > 65 and item <= 75):
#        ageCat.append(1)
#    elif item > 75:
#        ageCat.append(2)
        
        
#     data[ data['AGE'] <= 65, 'AGE'] = 0
#     data[(data['AGE'] > 65) & (data['AGE'] <= 75), 'AGE'] = 1
#     data[ data['AGE'] > 75, 'Afor dataset in combine:

# %%
data[['DX_bl', 'MMSE', 'CDRSB', 'ADAS13', "ADAS11"]].groupby('DX_bl', as_index=False).mean()
# Out:
#   DX_bl       MMSE     CDRSB     ADAS13     ADAS11
# 0    AD  21.544340  5.597928  33.111505  22.574929
# 1    CN  28.776790  0.321964   9.814644   6.228775
# 2  EMCI  27.807952  1.510886  13.353955   8.484399
# 3  LMCI  25.507735  3.066626  21.954324  14.083692
# 4   SMC  28.865455  0.202929   8.855967   5.635246

# %%
data['AgeBand'] = pd.cut(data['AGE'], 4)
data[['AgeBand', 'MMSE', 'CDRSB', 'ADAS13', "ADAS11"]].groupby('AgeBand', as_index=False).mean()
# Out:
#            AgeBand       MMSE     CDRSB     ADAS13     ADAS11
# 0  (54.363, 63.65]  26.543909  2.306358  17.448516  11.508728
# 1    (63.65, 72.9]  26.591319  2.157051  17.043620  11.230093
# 2    (72.9, 82.15]  26.281805  2.368561  19.031949  12.318413
# 3    (82.15, 91.4]  25.924581  2.714684  20.306657  13.095169

# %%
data[['AgeBand', 'DX_bl']]
# Out:
#                AgeBand DX_bl
# 0        (72.9, 82.15]    CN
# 1        (72.9, 82.15]    AD
# 2        (72.9, 82.15]    AD
# 3        (72.9, 82.15]    AD
# 4        (72.9, 82.15]    AD
# 5        (63.65, 72.9]  LMCI
# 6        (63.65, 72.9]  LMCI
# 7        (63.65, 72.9]  LMCI
# 8        (63.65, 72.9]  LMCI
# 9        (63.65, 72.9]  LMCI
# 10       (72.9, 82.15]    CN
# 11       (72.9, 82.15]    CN
# 12       (72.9, 82.15]    CN
# 13       (72.9, 82.15]    CN
# 14       (72.9, 82.15]    CN
# 15       (72.9, 82.15]  LMCI
# 16       (72.9, 82.15]  LMCI
# 17       (72.9, 82.15]  LMCI
# 18       (72.9, 82.15]  LMCI
# 19       (72.9, 82.15]  LMCI
# 20       (72.9, 82.15]    AD
# 21       (72.9, 82.15]    AD
# 22       (72.9, 82.15]    AD
# 23       (72.9, 82.15]    AD
# 24       (72.9, 82.15]    AD
# 25       (72.9, 82.15]    AD
# 26       (72.9, 82.15]    CN
# 27       (72.9, 82.15]    CN
# 28       (72.9, 82.15]    CN
# 29       (72.9, 82.15]    CN
# ...                ...   ...
# 11458    (63.65, 72.9]    CN
# 11459    (82.15, 91.4]  LMCI
# 11460    (63.65, 72.9]    CN
# 11461  (54.363, 63.65]  LMCI
# 11462    (72.9, 82.15]    CN
# 11463    (72.9, 82.15]  LMCI
# 11464    (63.65, 72.9]    CN
# 11465    (63.65, 72.9]    CN
# 11466    (63.65, 72.9]    CN
# 11467    (72.9, 82.15]    CN
# 11468    (72.9, 82.15]  LMCI
# 11469    (82.15, 91.4]    CN
# 11470    (63.65, 72.9]    CN
# 11471    (82.15, 91.4]    CN
# 11472    (82.15, 91.4]  LMCI
# 11473    (63.65, 72.9]   NaN
# 11474    (63.65, 72.9]  LMCI
# 11475    (72.9, 82.15]    CN
# 11476    (72.9, 82.15]  LMCI
# 11477    (63.65, 72.9]   NaN
# 11478    (63.65, 72.9]   NaN
# 11479    (63.65, 72.9]   NaN
# 11480    (72.9, 82.15]    CN
# 11481    (72.9, 82.15]    CN
# 11482    (63.65, 72.9]   NaN
# 11483  (54.363, 63.65]   NaN
# 11484    (72.9, 82.15]  EMCI
# 11485    (63.65, 72.9]   SMC
# 11486    (72.9, 82.15]   NaN
# 11487    (72.9, 82.15]    CN
#
# [11488 rows x 2 columns]

# %%
data.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER      ...        PTAU_bl   FDG_bl PIB_bl AV45_bl  Years_bl  \
# 0     Male      ...            NaN  1.36926    NaN     NaN  0.000000
# 1     Male      ...          22.83  1.09079    NaN     NaN  0.000000
# 2     Male      ...          22.83  1.09079    NaN     NaN  0.498289
# 3     Male      ...          22.83  1.09079    NaN     NaN  0.999316
# 4     Male      ...          22.83  1.09079    NaN     NaN  1.998630
#
#    Month_bl  Month   M           update_stamp        AgeBand
# 0   0.00000      0   0  2017-12-08 23:40:58.0  (72.9, 82.15]
# 1   0.00000      0   0  2017-12-08 23:40:58.0  (72.9, 82.15]
# 2   5.96721      6   6  2017-12-08 23:40:58.0  (72.9, 82.15]
# 3  11.96720     12  12  2017-12-08 23:40:58.0  (72.9, 82.15]
# 4  23.93440     24  24  2017-12-08 23:40:58.0  (72.9, 82.15]
#
# [5 rows x 110 columns]

# %%
from sklearn.preprocessing import LabelEncoder

categorize_age = LabelEncoder()
data['AGE_cat'] = categorize_age.fit_transform(data['AgeBand'])
data[['RID', 'AGE', 'AgeBand', 'AGE_cat']]
# Out:
#         RID   AGE          AgeBand  AGE_cat
# 0         2  74.3    (72.9, 82.15]        2
# 1         3  81.3    (72.9, 82.15]        2
# 2         3  81.3    (72.9, 82.15]        2
# 3         3  81.3    (72.9, 82.15]        2
# 4         3  81.3    (72.9, 82.15]        2
# 5         4  67.5    (63.65, 72.9]        1
# 6         4  67.5    (63.65, 72.9]        1
# 7         4  67.5    (63.65, 72.9]        1
# 8         4  67.5    (63.65, 72.9]        1
# 9         4  67.5    (63.65, 72.9]        1
# 10        5  73.7    (72.9, 82.15]        2
# 11        5  73.7    (72.9, 82.15]        2
# 12        5  73.7    (72.9, 82.15]        2
# 13        5  73.7    (72.9, 82.15]        2
# 14        5  73.7    (72.9, 82.15]        2
# 15        6  80.4    (72.9, 82.15]        2
# 16        6  80.4    (72.9, 82.15]        2
# 17        6  80.4    (72.9, 82.15]        2
# 18        6  80.4    (72.9, 82.15]        2
# 19        6  80.4    (72.9, 82.15]        2
# 20        7  75.4    (72.9, 82.15]        2
# 21        7  75.4    (72.9, 82.15]        2
# 22       10  73.9    (72.9, 82.15]        2
# 23       10  73.9    (72.9, 82.15]        2
# 24       10  73.9    (72.9, 82.15]        2
# 25       10  73.9    (72.9, 82.15]        2
# 26       14  78.5    (72.9, 82.15]        2
# 27       14  78.5    (72.9, 82.15]        2
# 28       14  78.5    (72.9, 82.15]        2
# 29       14  78.5    (72.9, 82.15]        2
# ...     ...   ...              ...      ...
# 11458  4587  65.7    (63.65, 72.9]        1
# 11459   626  83.2    (82.15, 91.4]        3
# 11460   677  70.8    (63.65, 72.9]        1
# 11461   679  62.9  (54.363, 63.65]        0
# 11462   684  77.4    (72.9, 82.15]        2
# 11463   698  74.3    (72.9, 82.15]        2
# 11464   731  71.5    (63.65, 72.9]        1
# 11465   734  72.6    (63.65, 72.9]        1
# 11466   751  70.9    (63.65, 72.9]        1
# 11467   767  73.0    (72.9, 82.15]        2
# 11468   802  80.9    (72.9, 82.15]        2
# 11469   907  88.6    (82.15, 91.4]        3
# 11470   969  70.0    (63.65, 72.9]        1
# 11471   981  84.3    (82.15, 91.4]        3
# 11472  1074  85.0    (82.15, 91.4]        3
# 11473  6117  65.4    (63.65, 72.9]        1
# 11474   214  65.1    (63.65, 72.9]        1
# 11475  4278  75.0    (72.9, 82.15]        2
# 11476  4889  75.6    (72.9, 82.15]        2
# 11477  6059  64.9    (63.65, 72.9]        1
# 11478  6110  71.6    (63.65, 72.9]        1
# 11479  6116  69.6    (63.65, 72.9]        1
# 11480  4396  78.4    (72.9, 82.15]        2
# 11481  4620  77.1    (72.9, 82.15]        2
# 11482  6062  67.4    (63.65, 72.9]        1
# 11483  6085  55.8  (54.363, 63.65]        0
# 11484  4301  74.6    (72.9, 82.15]        2
# 11485  5130  66.3    (63.65, 72.9]        1
# 11486  6097  74.6    (72.9, 82.15]        2
# 11487    35  76.9    (72.9, 82.15]        2
#
# [11488 rows x 4 columns]

# %%
type(data['AGE_cat'])
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER   ...      FDG_bl PIB_bl AV45_bl  Years_bl  Month_bl  Month   M  \
# 0     Male   ...     1.36926    NaN     NaN  0.000000   0.00000      0   0
# 1     Male   ...     1.09079    NaN     NaN  0.000000   0.00000      0   0
# 2     Male   ...     1.09079    NaN     NaN  0.498289   5.96721      6   6
# 3     Male   ...     1.09079    NaN     NaN  0.999316  11.96720     12  12
# 4     Male   ...     1.09079    NaN     NaN  1.998630  23.93440     24  24
#
#             update_stamp        AgeBand  AGE_cat
# 0  2017-12-08 23:40:58.0  (72.9, 82.15]        2
# 1  2017-12-08 23:40:58.0  (72.9, 82.15]        2
# 2  2017-12-08 23:40:58.0  (72.9, 82.15]        2
# 3  2017-12-08 23:40:58.0  (72.9, 82.15]        2
# 4  2017-12-08 23:40:58.0  (72.9, 82.15]        2
#
# [5 rows x 111 columns]
