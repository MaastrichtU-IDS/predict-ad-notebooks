# %% [markdown]
# # Data Preparation: MCI Patient Selection
# ADNIMERGE patient selection according to Massi's R screening file.
# This notebook is to serve as to get familiar with the ADNI dataset, the ADNIMERGE file, and select the MCI patients of interest for our models.
#
# Massi used the RID variable to see which rows refers to the same subject. Initally he included only those subjects that at VISCODE ==“bl” had a DX_bl == [“EMCI”] or DX_bl == [“LMCI”]. From this time he also took also the variables used as predicotrs. Then, for these subjects, he considered their 3 year followups (VISCODE in [bl,m03,m30,m36,m24,m18,m12,m06]) and see if at a certain point their DX became “Dementia”. in this case they were coded as converters, otherwise they were coded as non-converters. If conversion happened anytime along the 3 years, they were considered converters anyhow.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys

from collections import Counter 

# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/home/jovyan/work/DATA_PREPARATION/PATIENT_SCREENING'

# %% [markdown]
# ## Loading the ADNIMERGE.csv dataset
# The ADNIMERGE dataset can be found in the folder DATA_15_12_2017/Study_info. The data in this folder are limited to study info, clinical, sociodemographic and neuropsychological data. The ADNIMERGE dataset is basically one large dataset containing the most important features of the ADNI study, and most/all can also be found in the separate datasets in the DATA folder. In case you would like to know what all the abbreviations are, you can find all study codes in the so-called 'dictionary files, and the file ADNIMERGE_DICT in the Study_info folder contains specifically the codes for the ADNIMERGE data.
#
# More info on the ADNI study in general (centers included, cohorts-ADNI1, ADNIGO, ADNI2, ADNI3, study design etc.) can be found on the website: http://adni.loni.usc.edu/

# %%
#reading CSV file
data = pd.read_csv("ADNIMERGE.csv")

selected_columns = ['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
                    'DX_bl', 'AGE', 'PTGENDER', 'DX']

adnimerge = data[selected_columns]
adnimerge.head(10)
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER        DX
# 0     Male        CN
# 1     Male  Dementia
# 2     Male  Dementia
# 3     Male  Dementia
# 4     Male  Dementia
# 5     Male       MCI
# 6     Male       MCI
# 7     Male       MCI
# 8     Male       MCI
# 9     Male       MCI

# %%
# get all column names of ADNIMERGE
data.columns.values
# Out:
# array(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
#        'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT', 'PTRACCAT',
#        'PTMARRY', 'APOE4', 'FDG', 'PIB', 'AV45', 'ABETA', 'TAU', 'PTAU',
#        'CDRSB', 'ADAS11', 'ADAS13', 'ADASQ4', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting',
#        'LDELTOTAL', 'DIGITSCOR', 'TRABSCOR', 'FAQ', 'MOCA', 'EcogPtMem',
#        'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan',
#        'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'FLDSTRENG', 'FSVERSION', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'ICV', 'DX', 'mPACCdigit', 'mPACCtrailsB', 'EXAMDATE_bl',
#        'CDRSB_bl', 'ADAS11_bl', 'ADAS13_bl', 'ADASQ4_bl', 'MMSE_bl',
#        'RAVLT_immediate_bl', 'RAVLT_learning_bl', 'RAVLT_forgetting_bl',
#        'RAVLT_perc_forgetting_bl', 'FAQ_bl', 'mPACCdigit_bl',
#        'mPACCtrailsB_bl', 'FLDSTRENG_bl', 'FSVERSION_bl', 'Ventricles_bl',
#        'Hippocampus_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl', 'ICV_bl', 'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl',
#        'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl',
#        'EcogSPLang_bl', 'EcogSPVisspat_bl', 'EcogSPPlan_bl',
#        'EcogSPOrgan_bl', 'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'ABETA_bl',
#        'TAU_bl', 'PTAU_bl', 'FDG_bl', 'PIB_bl', 'AV45_bl', 'Years_bl',
#        'Month_bl', 'Month', 'M', 'update_stamp'], dtype=object)

# %% [markdown]
# ## Step 1: Including only MCI subjects

# %%
#code from Massi
to_include_mci = np.unique(np.array(adnimerge["RID"].loc[adnimerge["DX_bl"].isin(["EMCI","LMCI"])]))

adnimerge2 = adnimerge.loc[adnimerge["RID"].isin(to_include_mci)]
adnimerge2.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER   DX
# 5     Male  MCI
# 6     Male  MCI
# 7     Male  MCI
# 8     Male  MCI
# 9     Male  MCI

# %%
to_include_mci.shape
# Out:
# (790,)

# %%
adnimerge2[(adnimerge2["VISCODE"] == "bl") & (adnimerge2["DX"] == "Dementia")]
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 762    332  021_S_0332      bl    21   ADNI1    ADNI1  2006-04-19  LMCI  69.9
# 2061   995  100_S_0995      bl   100   ADNI1    ADNI1  2006-11-13  LMCI  78.5
# 2364  1154  100_S_1154      bl   100   ADNI1    ADNI1  2007-01-30  LMCI  76.6
# 5299    78  023_S_0078      bl    23   ADNI1    ADNI1  2006-01-12  LMCI  76.0
# 5609   190  100_S_0190      bl   100   ADNI1    ADNI1  2006-05-16  LMCI  78.8
# 7753  1226  100_S_1226      bl   100   ADNI1    ADNI1  2007-02-15  LMCI  82.6
#
#      PTGENDER        DX
# 762      Male  Dementia
# 2061   Female  Dementia
# 2364     Male  Dementia
# 5299   Female  Dementia
# 5609     Male  Dementia
# 7753     Male  Dementia

# %%
#selecting subjects with DX_bl of EMCI and LMCI
adnimerge_MCI = adnimerge[adnimerge["DX_bl"].isin(["EMCI", "LMCI"])]
adnimerge_MCI.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER   DX
# 5     Male  MCI
# 6     Male  MCI
# 7     Male  MCI
# 8     Male  MCI
# 9     Male  MCI

# %%
#selecting RIDs of these subjects
MCI_patients = np.unique(adnimerge2["RID"])
MCI_patients
# Out:
# array([   4,    6,   30,   33,   38,   41,   42,   44,   45,   50,   51,
#          54,   57,   60,   77,   78,   80,   87,   98,  101,  102,  103,
#         107,  108,  111,  112,  116,  126,  128,  135,  138,  141,  142,
#         150,  155,  160,  161,  168,  169,  176,  178,  179,  182,  187,
#         188,  190,  195,  200,  204,  205,  214,  217,  222,  225,  227,
#         231,  240,  241,  243,  249,  256,  258,  269,  273,  276,  282,
#         284,  285,  288,  289,  290,  291,  292,  293,  296,  307,  314,
#         324,  325,  331,  332,  336,  339,  344,  351,  354,  361,  362,
#         376,  377,  378,  384,  388,  389,  390,  393,  394,  397,  401,
#         406,  407,  408,  409,  410,  414,  417,  423,  424,  429,  434,
#         442,  445,  448,  449,  450,  458,  461,  464,  469,  476,  478,
#         481,  485,  501,  505,  507,  511,  513,  514,  518,  531,  539,
# 278  108  123_S_0108     m60   123  ADNIGO    ADNI1  2011-02-15  LMCI  78.2
# 286  111  099_S_0111      bl    99   ADNI1    ADNI1  2006-01-31  LMCI  75.8
# 287  111  099_S_0111     m06    99   ADNI1    ADNI1  2006-08-21  LMCI  75.8
# 288  111  099_S_0111     m12    99   ADNI1    ADNI1  2007-02-08  LMCI  75.8
# 289  112  127_S_0112      bl   127   ADNI1    ADNI1  2006-02-01  LMCI  70.6
# 290  112  127_S_0112     m06   127   ADNI1    ADNI1  2006-07-27  LMCI  70.6
# 291  112  127_S_0112     m12   127   ADNI1    ADNI1  2007-02-07  LMCI  70.6
# 292  112  127_S_0112     m18   127   ADNI1    ADNI1  2007-07-30  LMCI  70.6
# 293  112  127_S_0112     m24   127   ADNI1    ADNI1  2008-01-29  LMCI  70.6
# 294  112  127_S_0112     m36   127   ADNI1    ADNI1  2009-01-23  LMCI  70.6
# 295  112  127_S_0112     m48   127   ADNI1    ADNI1  2010-01-28  LMCI  70.6
# 302  116  027_S_0116      bl    27   ADNI1    ADNI1  2006-02-15  LMCI  78.4
# 303  116  027_S_0116     m06    27   ADNI1    ADNI1  2006-08-30  LMCI  78.4
# 304  116  027_S_0116     m12    27   ADNI1    ADNI1  2007-02-06  LMCI  78.4
# 305  116  027_S_0116     m18    27   ADNI1    ADNI1  2007-08-08  LMCI  78.4
# 306  116  027_S_0116     m48    27   ADNI1    ADNI1  2010-02-17  LMCI  78.4
#
#     PTGENDER        DX
# 5       Male       MCI
# 6       Male       MCI
# 7       Male       MCI
# 8       Male       MCI
# 9       Male       MCI
# 15    Female       MCI
# 16    Female       MCI
# 17    Female       MCI
# 18    Female       MCI
# 19    Female       MCI
# 55      Male       MCI
# 56      Male       MCI
# 61      Male       MCI
# 62      Male       MCI
# 63      Male       MCI
# 68    Female       MCI
# 69      Male       MCI
# 70      Male       MCI
# 71      Male  Dementia
# 72      Male  Dementia
# 73      Male  Dementia
# 74      Male  Dementia
# 75      Male  Dementia
# 83    Female       MCI
# 84      Male       MCI
# 85      Male       MCI
# 90      Male  Dementia
# 91      Male       MCI
# 92      Male       MCI
# 93      Male       MCI
# ..       ...       ...
# 258   Female       MCI
# 259     Male       MCI
# 260     Male       MCI
# 266   Female       MCI
# 267   Female       MCI
# 268   Female       MCI
# 269   Female       MCI
# 270   Female       MCI
# 271   Female       MCI
# 273     Male       MCI
# 274     Male       MCI
# 275     Male  Dementia
# 276     Male  Dementia
# 277     Male  Dementia
# 278     Male  Dementia
# 286   Female       MCI
# 287   Female       MCI
# 288   Female  Dementia
# 289     Male       MCI
# 290     Male        CN
# 291     Male       MCI
# 292     Male       MCI
# 293     Male        CN
# 294     Male        CN
# 295     Male        CN
# 302     Male       MCI
# 303     Male       MCI
# 304     Male       MCI
# 305     Male       MCI
# 306     Male       MCI
#
# [100 rows x 11 columns]

# %% [markdown]
# ### showing discrepancy when only selecting for DX_bl and not DX

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
adnimerge_MCI_patients[(adnimerge_MCI_patients["VISCODE"] == "bl") & (adnimerge_MCI_patients["DX"] == "Dementia")]
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 762    332  021_S_0332      bl    21   ADNI1    ADNI1  2006-04-19  LMCI  69.9
# 2061   995  100_S_0995      bl   100   ADNI1    ADNI1  2006-11-13  LMCI  78.5
# 2364  1154  100_S_1154      bl   100   ADNI1    ADNI1  2007-01-30  LMCI  76.6
# 5299    78  023_S_0078      bl    23   ADNI1    ADNI1  2006-01-12  LMCI  76.0
# 5609   190  100_S_0190      bl   100   ADNI1    ADNI1  2006-05-16  LMCI  78.8
# 7753  1226  100_S_1226      bl   100   ADNI1    ADNI1  2007-02-15  LMCI  82.6
#
#      PTGENDER        DX
# 762      Male  Dementia
# 2061   Female  Dementia
# 2364     Male  Dementia
# 5299   Female  Dementia
# 5609     Male  Dementia
# 7753     Male  Dementia

# %%
#getting RIDs from these discrepancy cases
inconsequent_RID = np.unique(adnimerge_MCI_patients[(adnimerge_MCI_patients["VISCODE"] == "bl") & (adnimerge_MCI_patients["DX"] == "Dementia")]["RID"])
inconsequent_RID
# Out:
# array([  78,  190,  332,  995, 1154, 1226])

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
adnimerge_MCI_patients[adnimerge_MCI_patients["RID"] == 332]
# Out:
#      RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 762  332  021_S_0332      bl    21   ADNI1    ADNI1  2006-04-19  LMCI  69.9
# 763  332  021_S_0332     m06    21   ADNI1    ADNI1  2006-10-19  LMCI  69.9
# 764  332  021_S_0332     m12    21   ADNI1    ADNI1  2007-04-19  LMCI  69.9
#
#     PTGENDER        DX
# 762     Male  Dementia
# 763     Male  Dementia
# 764     Male  Dementia

# %% [markdown]
# ### selecting for DX_bl and DX

# %%
#selecting subjects RID with DX_bl of EMCI and LMCI and DX of MCI
MCI_patients_RID2 = np.unique(adnimerge[(adnimerge["DX_bl"].isin(["EMCI", "LMCI"])) & (adnimerge["DX"] == "MCI")]["RID"])
MCI_patients_RID2
# Out:
# array([   4,    6,   30,   33,   38,   41,   42,   44,   45,   50,   51,
#          54,   57,   60,   77,   80,   87,   98,  101,  102,  103,  107,
#         108,  111,  112,  116,  126,  128,  135,  138,  141,  142,  150,
#         155,  160,  161,  168,  169,  176,  178,  179,  182,  187,  188,
#         195,  200,  204,  205,  214,  217,  222,  225,  227,  231,  240,
#         241,  243,  249,  256,  258,  269,  273,  276,  282,  284,  285,
#         288,  289,  290,  291,  292,  293,  296,  307,  314,  324,  325,
#         331,  336,  339,  344,  351,  354,  361,  362,  376,  377,  378,
#         384,  388,  389,  390,  393,  394,  397,  401,  406,  407,  408,
#         409,  410,  414,  417,  423,  424,  429,  434,  442,  445,  448,
#         449,  450,  458,  461,  464,  469,  476,  478,  481,  485,  501,
#         505,  507,  511,  513,  514,  518,  531,  539,  544,  546,  549,
#         551,  552,  557,  563,  566,  567,  568,  572,  579,  588,  598,
#         604,  607,  608,  611,  613,  621,  625,  626,  629,  631,  638,
#         641,  644,  649,  656,  658,  667,  668,  669,  671,  673,  675,
#         679,  695,  697,  698,  702,  708,  709,  715,  718,  721,  723,
#         725,  727,  729,  748,  750,  752,  769,  770,  771,  782,  783,
#        4331, 4332, 4346, 4351, 4354, 4359, 4360, 4363, 4366, 4377, 4380,
#        4383, 4390, 4392, 4394, 4395, 4402, 4403, 4404, 4405, 4406, 4408,
#        4414, 4415, 4417, 4419, 4420, 4423, 4426, 4430, 4431, 4432, 4434,
#        4438, 4443, 4444, 4447, 4456, 4458, 4462, 4463, 4465, 4467, 4473,
#        4475, 4480, 4489, 4498, 4502, 4507, 4510, 4513, 4514, 4515, 4521,
#        4522, 4524, 4530, 4531, 4538, 4539, 4542, 4547, 4548, 4553, 4556,
#        4557, 4562, 4564, 4565, 4582, 4584, 4590, 4595, 4596, 4597, 4601,
#        4603, 4605, 4610, 4611, 4613, 4614, 4621, 4623, 4624, 4629, 4630,
#        4631, 4633, 4635, 4636, 4646, 4653, 4659, 4661, 4668, 4671, 4674,
#        4675, 4678, 4679, 4680, 4689, 4694, 4708, 4711, 4712, 4713, 4714,
#        4715, 4720, 4721, 4729, 4736, 4741, 4742, 4743, 4744, 4746, 4757,
#        4764, 4765, 4767, 4769, 4777, 4780, 4782, 4784, 4791, 4793, 4796,
#        4798, 4799, 4803, 4804, 4805, 4806, 4807, 4809, 4814, 4815, 4816,
#        4817, 4823, 4825, 4838, 4842, 4844, 4849, 4852, 4857, 4858, 4862,
#        4868, 4871, 4873, 4874, 4876, 4877, 4883, 4885, 4888, 4889, 4891,
#        4893, 4897, 4898, 4899, 4902, 4903, 4904, 4907, 4909, 4914, 4917,
#        4918, 4919, 4920, 4922, 4925, 4926, 4928, 4929, 4936, 4941, 4943,
#        4944, 4945, 4947, 4955, 4958, 4966, 4974, 4976, 4985, 4986, 4987,
#        4989, 5000, 5007, 5014, 5026, 5031, 5047, 5066, 5135, 5160])

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
adnimerge_MCI_patients2 = adnimerge[adnimerge["RID"].isin(MCI_patients_RID2)]
adnimerge_MCI_patients2.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER   DX
# 5     Male  MCI
# 6     Male  MCI
# 7     Male  MCI
# 8     Male  MCI
# 9     Male  MCI

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
adnimerge_MCI_patients2[(adnimerge_MCI_patients2["VISCODE"] == "bl") & (adnimerge_MCI_patients2["DX"] == "Dementia")]
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 7753  1226  100_S_1226      bl   100   ADNI1    ADNI1  2007-02-15  LMCI  82.6
#
#      PTGENDER        DX
# 7753     Male  Dementia

# %%
#check whether other discrepancy cases are removed
adnimerge_MCI_patients2[adnimerge_MCI_patients2["RID"] == 332]
# Out:
# Empty DataFrame
# Columns: [RID, PTID, VISCODE, SITE, COLPROT, ORIGPROT, EXAMDATE, DX_bl, AGE, PTGENDER, DX]
# Index: []

# %%
#check out this particular case 1226
adnimerge_MCI_patients2[adnimerge_MCI_patients2["RID"] == 1226]
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 2484  1226  100_S_1226     m06   100   ADNI1    ADNI1  2007-08-27  LMCI  82.6
# 2485  1226  100_S_1226     m24   100   ADNI1    ADNI1  2009-02-17  LMCI  82.6
# 2486  1226  100_S_1226     m36   100   ADNI1    ADNI1  2010-03-30  LMCI  82.6
# 2487  1226  100_S_1226     m48   100  ADNIGO    ADNI1  2011-02-09  LMCI  82.6
# 7753  1226  100_S_1226      bl   100   ADNI1    ADNI1  2007-02-15  LMCI  82.6
# 7754  1226  100_S_1226     m12   100   ADNI1    ADNI1  2008-02-07  LMCI  82.6
# 7755  1226  100_S_1226     m18   100   ADNI1    ADNI1  2008-08-05  LMCI  82.6
# 7756  1226  100_S_1226     m30   100   ADNI1    ADNI1  2009-08-04  LMCI  82.6
# 7757  1226  100_S_1226     m54   100  ADNIGO    ADNI1  2011-08-10  LMCI  82.6
#
#      PTGENDER        DX
# 2484     Male  Dementia
# 2485     Male  Dementia
# 2486     Male  Dementia
# 2487     Male       MCI
# 7753     Male  Dementia
# 7754     Male  Dementia
# 7755     Male  Dementia
# 7756     Male       NaN
# 7757     Male       NaN

# %% [markdown]
# ### selecting for DX_bl, DX and VISCODE bl

# %%
#selecting subjects RID with DX_bl of EMCI and LMCI and DX of MCI and baseline visitcode
MCI_patients_RID3 = np.unique(adnimerge[(adnimerge["DX_bl"].isin(["EMCI", "LMCI"])) & (adnimerge["DX"] == "MCI") & (adnimerge["VISCODE"] == "bl")]["RID"])
MCI_patients_RID3.shape
# Out:
# (779,)

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
#also screened RIDs for baseline visit
adnimerge_MCI_patients3 = adnimerge[adnimerge["RID"].isin(MCI_patients_RID3)]
adnimerge_MCI_patients3.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER   DX
# 5     Male  MCI
# 6     Male  MCI
# 7     Male  MCI
# 8     Male  MCI
# 9     Male  MCI

# %%
adnimerge_MCI_patients3[adnimerge_MCI_patients3["RID"] == 332]
# Out:
# Empty DataFrame
# Columns: [RID, PTID, VISCODE, SITE, COLPROT, ORIGPROT, EXAMDATE, DX_bl, AGE, PTGENDER, DX]
# Index: []

# %%
#showing discrepancy between DX_bl and DX at VICSODE bl, slecting only baseline visit
#also removed RIDs at baseline discrepancy

#adnimerge_MCI_patients3[adnimerge_MCI_patients3["DX"] == "Dementia"]

# %% [markdown]
# ### Comparing MCI selection of my protocol vs Massi

# %%
#my MCI selection (from MCI_patients_RID3)
adnimerge_MCI_patients3.head(10)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
#
#    PTGENDER   DX
# 5      Male  MCI
# 6      Male  MCI
# 7      Male  MCI
# 8      Male  MCI
# 9      Male  MCI
# 15   Female  MCI
# 16   Female  MCI
# 17   Female  MCI
# 18   Female  MCI
# 19   Female  MCI

# %%
adnimerge_MCI_patients3.shape
# Out:
# (6306, 11)

# %%
#MCI selection of Massi (based on mci_to_include)
adnimerge2.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER   DX
# 5     Male  MCI
# 6     Male  MCI
# 7     Male  MCI
# 8     Male  MCI
# 9     Male  MCI

# %%
#difference of 35 records
adnimerge2.shape
# Out:
# (6341, 11)

# %%
#find discrepancy RIDs as described above, and select these RIDs from dataframe
#comes to total number of 30 records, still 5 records difference 
wrongRID_adnimerge2 = np.unique(adnimerge2[(adnimerge2["VISCODE"] == "bl") & (adnimerge2["DX"] == "Dementia")]["RID"])
adnimerge2[adnimerge2["RID"].isin(wrongRID_adnimerge2)]
# Out:
#        RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 184     78  023_S_0078     m18    23   ADNI1    ADNI1  2007-07-24  LMCI  76.0
# 469    190  100_S_0190     m12   100   ADNI1    ADNI1  2007-05-08  LMCI  78.8
# 762    332  021_S_0332      bl    21   ADNI1    ADNI1  2006-04-19  LMCI  69.9
# 763    332  021_S_0332     m06    21   ADNI1    ADNI1  2006-10-19  LMCI  69.9
# 764    332  021_S_0332     m12    21   ADNI1    ADNI1  2007-04-19  LMCI  69.9
# 2061   995  100_S_0995      bl   100   ADNI1    ADNI1  2006-11-13  LMCI  78.5
# 2062   995  100_S_0995     m06   100   ADNI1    ADNI1  2007-05-09  LMCI  78.5
# 2063   995  100_S_0995     m12   100   ADNI1    ADNI1  2007-11-19  LMCI  78.5
# 2064   995  100_S_0995     m24   100   ADNI1    ADNI1  2009-02-06  LMCI  78.5
# 2065   995  100_S_0995     m36   100   ADNI1    ADNI1  2009-11-10  LMCI  78.5
# 2364  1154  100_S_1154      bl   100   ADNI1    ADNI1  2007-01-30  LMCI  76.6
# 2484  1226  100_S_1226     m06   100   ADNI1    ADNI1  2007-08-27  LMCI  82.6
# 2485  1226  100_S_1226     m24   100   ADNI1    ADNI1  2009-02-17  LMCI  82.6
# 2486  1226  100_S_1226     m36   100   ADNI1    ADNI1  2010-03-30  LMCI  82.6
# 2487  1226  100_S_1226     m48   100  ADNIGO    ADNI1  2011-02-09  LMCI  82.6
# 5299    78  023_S_0078      bl    23   ADNI1    ADNI1  2006-01-12  LMCI  76.0
# 5300    78  023_S_0078     m06    23   ADNI1    ADNI1  2006-07-11  LMCI  76.0
# 5301    78  023_S_0078     m12    23   ADNI1    ADNI1  2007-01-11  LMCI  76.0
# 5609   190  100_S_0190      bl   100   ADNI1    ADNI1  2006-05-16  LMCI  78.8
# 5610   190  100_S_0190     m06   100   ADNI1    ADNI1  2006-11-07  LMCI  78.8
# 5611   190  100_S_0190     m18   100   ADNI1    ADNI1  2007-11-07  LMCI  78.8
# 5612   190  100_S_0190     m24   100   ADNI1    ADNI1  2008-05-01  LMCI  78.8
# 7272   995  100_S_0995     m18   100   ADNI1    ADNI1  2008-05-06  LMCI  78.5
# 7616  1154  100_S_1154     m06   100   ADNI1    ADNI1  2007-07-10  LMCI  76.6
# 7617  1154  100_S_1154     m12   100   ADNI1    ADNI1  2008-03-28  LMCI  76.6
# 7753  1226  100_S_1226      bl   100   ADNI1    ADNI1  2007-02-15  LMCI  82.6
# 7754  1226  100_S_1226     m12   100   ADNI1    ADNI1  2008-02-07  LMCI  82.6
# 7755  1226  100_S_1226     m18   100   ADNI1    ADNI1  2008-08-05  LMCI  82.6
# 7756  1226  100_S_1226     m30   100   ADNI1    ADNI1  2009-08-04  LMCI  82.6
# 7757  1226  100_S_1226     m54   100  ADNIGO    ADNI1  2011-08-10  LMCI  82.6
#
#      PTGENDER        DX
# 184    Female  Dementia
# 469      Male  Dementia
# 762      Male  Dementia
# 763      Male  Dementia
# 764      Male  Dementia
# 2061   Female  Dementia
# 2062   Female  Dementia
# 2063   Female  Dementia
# 2064   Female  Dementia
# 2065   Female  Dementia
# 2364     Male  Dementia
# 2484     Male  Dementia
# 2485     Male  Dementia
# 2486     Male  Dementia
# 2487     Male       MCI
# 5299   Female  Dementia
# 5300   Female  Dementia
# 5301   Female  Dementia
# 5609     Male  Dementia
# 5610     Male  Dementia
# 5611     Male  Dementia
# 5612     Male  Dementia
# 7272   Female  Dementia
# 7616     Male  Dementia
# 7617     Male  Dementia
# 7753     Male  Dementia
# 7754     Male  Dementia
# 7755     Male  Dementia
# 7756     Male       NaN
# 7757     Male       NaN

# %%
#6 RIDs are considered these dicrepancy RIDs
wrongRID_adnimerge2
# Out:
# array([  78,  190,  332,  995, 1154, 1226])

# %%
#find the missing RIDs in MCI_patients_RID3 (my selection) list as compared to to_include_mci (Massis selection) list
lostRID = [x for x in to_include_mci if x not in MCI_patients_RID3]
lostRID
# Out:
# [78, 190, 332, 995, 1154, 1226, 2071, 2314, 4085, 4575, 4622]

# %%
#check the additional RIDs in the adnimerge2 dataframe
#they represent NaN values for DX (which are not selected in my approach)
#Massi is probably eliminating these subjects in his second step, where he is going to select
#subjects with follow-up of m36 and higher, which these subjects don't have 
adnimerge2[adnimerge2["RID"].isin([2071, 2314, 4085, 4575, 4622])]
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 4537   4622  024_S_4622      bl    24   ADNI2    ADNI2  2012-04-06  LMCI
# 4715   4575  016_S_4575      bl    16   ADNI2    ADNI2  2012-05-09  EMCI
# 8987   4085  035_S_4085      bl    35   ADNI2    ADNI2  2011-07-11  EMCI
# 11186  2071  098_S_2071      bl    98  ADNIGO   ADNIGO  2010-09-20  EMCI
# 11187  2314  128_S_2314      bl   128  ADNIGO   ADNIGO  2011-04-21  EMCI
#
#         AGE PTGENDER   DX
# 4537   76.0     Male  NaN
# 4715   62.1   Female  NaN
# 8987   55.5     Male  NaN
# 11186  84.9     Male  NaN
# 11187  65.7     Male  NaN

# %% [markdown]
# ## Step 2 Selecting MCI subjects with follow-up available untill at least m36
# (or m36 and higher?)

# %%
#VISCODE labels in dataframe my approach
np.unique(adnimerge_MCI_patients3["VISCODE"].values)
# Out:
# array(['bl', 'm03', 'm06', 'm102', 'm108', 'm114', 'm12', 'm120', 'm126',
#        'm132', 'm144', 'm18', 'm24', 'm30', 'm36', 'm42', 'm48', 'm54',
#        'm60', 'm66', 'm72', 'm78', 'm84', 'm90', 'm96'], dtype=object)

# %%
#VISCODE labels in dataframe my approach
#count number of labels in dataset and compare to label count Massi
adnimerge_MCI_patients3["VISCODE"].groupby(adnimerge_MCI_patients3["VISCODE"].values).count()
# Out:
# bl      779
# m03     373
# m06     731
# m102      2
# m108     54
# m114      1
# m12     708
# m120     32
# m126      1
# m132     12
# m144      1
# m18     616
# m24     605
# m30     403
# m36     523
# m42     163
# m48     352
# m54     109
# m60     232
# m66     109
# m72     170
# m78     103
# m84      97
# m90      55
# m96      75
# Name: VISCODE, dtype: int64

# %%
#VISCODE labels in Massi's approach
np.unique(adnimerge2["VISCODE"].values)
# Out:
# array(['bl', 'm03', 'm06', 'm102', 'm108', 'm114', 'm12', 'm120', 'm126',
#        'm132', 'm144', 'm18', 'm24', 'm30', 'm36', 'm42', 'm48', 'm54',
#        'm60', 'm66', 'm72', 'm78', 'm84', 'm90', 'm96'], dtype=object)

# %%
#VISCODE labels in Massi's approach
#count number of labels in dataset and compare to label count Massi
adnimerge2["VISCODE"].groupby(adnimerge2["VISCODE"].values).count()
# Out:
# bl      790
# m03     373
# m06     737
# m102      2
# m108     54
# m114      1
# m12     714
# m120     32
# m126      1
# m132     12
# m144      1
# m18     620
# m24     608
# m30     404
# m36     525
# m42     163
# m48     353
# m54     110
# m60     232
# m66     109
# m72     170
# m78     103
# m84      97
# m90      55
# m96      75
# Name: VISCODE, dtype: int64

# %%
#code Massi
# INCLUDE ONLY SUBJECTS WITH INFO OF CONVERTION AT LEAST YEAR 3
to_include_time = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36"]
to_include_subjects = np.unique(np.array(adnimerge2["RID"].loc[adnimerge2["VISCODE"].isin(to_include_time)]))
adnimerge3 = adnimerge2.loc[adnimerge2["RID"].isin(to_include_subjects)]
adnimerge3.head(50)
# Out:
#      RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5      4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6      4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7      4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8      4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9      4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15     6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16     6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17     6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18     6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19     6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55    33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# 56    33  035_S_0033     m36    35   ADNI1    ADNI1  2009-01-09  LMCI  83.3
# 68    41  007_S_0041     m06     7   ADNI1    ADNI1  2006-05-15  LMCI  70.9
# 69    42  023_S_0042      bl    23   ADNI1    ADNI1  2005-11-10  LMCI  72.8
# 70    42  023_S_0042     m06    23   ADNI1    ADNI1  2006-05-02  LMCI  72.8
# 71    42  023_S_0042     m12    23   ADNI1    ADNI1  2006-11-09  LMCI  72.8
# 72    42  023_S_0042     m18    23   ADNI1    ADNI1  2007-05-10  LMCI  72.8
# 73    42  023_S_0042     m24    23   ADNI1    ADNI1  2007-11-30  LMCI  72.8
# 74    42  023_S_0042     m36    23   ADNI1    ADNI1  2008-12-05  LMCI  72.8
# 75    42  023_S_0042     m48    23   ADNI1    ADNI1  2010-03-18  LMCI  72.8
# 90    50  123_S_0050     m18   123   ADNI1    ADNI1  2007-06-20  LMCI  77.6
# 91    51  099_S_0051      bl    99   ADNI1    ADNI1  2005-12-08  LMCI  66.5
# 92    51  099_S_0051     m06    99   ADNI1    ADNI1  2006-05-30  LMCI  66.5
# 93    51  099_S_0051     m12    99   ADNI1    ADNI1  2006-12-26  LMCI  66.5
# 94    51  099_S_0051     m18    99   ADNI1    ADNI1  2007-07-03  LMCI  66.5
# 95    51  099_S_0051     m24    99   ADNI1    ADNI1  2007-12-11  LMCI  66.5
# 96    51  099_S_0051     m36    99   ADNI1    ADNI1  2008-12-11  LMCI  66.5
# 101   54  099_S_0054      bl    99   ADNI1    ADNI1  2005-12-16  LMCI  81.0
# 102   54  099_S_0054     m06    99   ADNI1    ADNI1  2006-07-13  LMCI  81.0
# 103   54  099_S_0054     m12    99   ADNI1    ADNI1  2006-12-27  LMCI  81.0
# 104   54  099_S_0054     m24    99   ADNI1    ADNI1  2007-12-28  LMCI  81.0
# 112   57  018_S_0057      bl    18   ADNI1    ADNI1  2006-01-06  LMCI  77.3
# 113   57  018_S_0057     m06    18   ADNI1    ADNI1  2006-08-18  LMCI  77.3
# 114   57  018_S_0057     m12    18   ADNI1    ADNI1  2007-01-05  LMCI  77.3
# 115   57  018_S_0057     m18    18   ADNI1    ADNI1  2007-08-21  LMCI  77.3
# 179   77  067_S_0077      bl    67   ADNI1    ADNI1  2006-02-08  LMCI  79.7
# 180   77  067_S_0077     m06    67   ADNI1    ADNI1  2006-08-21  LMCI  79.7
# 181   77  067_S_0077     m12    67   ADNI1    ADNI1  2007-02-23  LMCI  79.7
# 182   77  067_S_0077     m18    67   ADNI1    ADNI1  2007-08-30  LMCI  79.7
# 183   77  067_S_0077     m24    67   ADNI1    ADNI1  2008-06-23  LMCI  79.7
# 185   80  018_S_0080      bl    18   ADNI1    ADNI1  2006-01-13  LMCI  85.0
# 186   80  018_S_0080     m06    18   ADNI1    ADNI1  2006-07-19  LMCI  85.0
# 187   80  018_S_0080     m12    18   ADNI1    ADNI1  2007-01-09  LMCI  85.0
# 245   98  067_S_0098      bl    67   ADNI1    ADNI1  2006-03-29  LMCI  84.4
# 246   98  067_S_0098     m06    67   ADNI1    ADNI1  2007-01-09  LMCI  84.4
# 247   98  067_S_0098     m12    67   ADNI1    ADNI1  2007-04-04  LMCI  84.4
# 248   98  067_S_0098     m36    67   ADNI1    ADNI1  2009-04-02  LMCI  84.4
# 249  101  007_S_0101      bl     7   ADNI1    ADNI1  2006-01-04  LMCI  73.6
# 250  101  007_S_0101     m06     7   ADNI1    ADNI1  2006-07-06  LMCI  73.6
# 251  101  007_S_0101     m12     7   ADNI1    ADNI1  2007-01-29  LMCI  73.6
#
#     PTGENDER        DX
# 5       Male       MCI
# 6       Male       MCI
# 7       Male       MCI
# 8       Male       MCI
# 9       Male       MCI
# 15    Female       MCI
# 16    Female       MCI
# 17    Female       MCI
# 18    Female       MCI
# 19    Female       MCI
# 55      Male       MCI
# 56      Male       MCI
# 68    Female       MCI
# 69      Male       MCI
# 70      Male       MCI
# 71      Male  Dementia
# 72      Male  Dementia
# 73      Male  Dementia
# 74      Male  Dementia
# 75      Male  Dementia
# 90      Male  Dementia
# 91      Male       MCI
# 92      Male       MCI
# 93      Male       MCI
# 94      Male       MCI
# 95      Male       MCI
# 96      Male       MCI
# 101   Female       MCI
# 102   Female       MCI
# 103   Female  Dementia
# 104   Female  Dementia
# 112     Male       MCI
# 113     Male       MCI
# 114     Male       MCI
# 115     Male  Dementia
# 179     Male       MCI
# 180     Male       MCI
# 181     Male  Dementia
# 182     Male  Dementia
# 183     Male  Dementia
# 185     Male       MCI
# 186     Male       MCI
# 187     Male       MCI
# 245   Female       MCI
# 246   Female       MCI
# 247   Female       MCI
# 248   Female  Dementia
# 249     Male       MCI
# 250     Male       MCI
# 251     Male       MCI

# %%
# OF THESE SUBJECTS, KEEP ONLY INFO OF CONVERTION BY YEAR 3
to_include_time_2 = ["bl","m03","m30","m36","m24","m18","m12","m06"]
adnimerge_selected_massi = adnimerge3.loc[adnimerge3["VISCODE"].isin(to_include_time_2)]
adnimerge_selected_massi.head(50)
np.count_nonzero(np.unique(adnimerge_selected_massi["RID"]))
# Out:
# 550

# %%
#check what difference it gives when using on m36 -- 25 subjects less (who apparently don't have m36)
#INCLUDE ONLY SUBJECTS WITH VISCODE of m36 available
visitcode_required = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36"]
visitcode_m36 = ["m36"]
subjects_included = np.unique(adnimerge2[adnimerge2["VISCODE"].isin(visitcode_m36)]["RID"])
adnimerge4 = adnimerge2.loc[adnimerge2["RID"].isin(subjects_included)]
adnimerge4.head(50)
np.count_nonzero(np.unique(adnimerge4["RID"]))
# Out:
# 525

# %% [markdown]
# Now cleaning this code and applying this approach to the dataframe adnimerge_MCI_patients3

# %%
# INCLUDE ONLY SUBJECTS WITH INFO OF CONVERTION AT LEAST YEAR 3
visitcode_required = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36"]
MCI_patients_RID4 = np.unique(adnimerge_MCI_patients3[adnimerge_MCI_patients3["VISCODE"].isin(visitcode_required)]["RID"])
adnimerge_MCI_patients4 = adnimerge_MCI_patients3.loc[adnimerge_MCI_patients3["RID"].isin(MCI_patients_RID4)]
adnimerge_MCI_patients4.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# 56   33  035_S_0033     m36    35   ADNI1    ADNI1  2009-01-09  LMCI  83.3
# 68   41  007_S_0041     m06     7   ADNI1    ADNI1  2006-05-15  LMCI  70.9
# 69   42  023_S_0042      bl    23   ADNI1    ADNI1  2005-11-10  LMCI  72.8
# 70   42  023_S_0042     m06    23   ADNI1    ADNI1  2006-05-02  LMCI  72.8
# 71   42  023_S_0042     m12    23   ADNI1    ADNI1  2006-11-09  LMCI  72.8
# 72   42  023_S_0042     m18    23   ADNI1    ADNI1  2007-05-10  LMCI  72.8
# 73   42  023_S_0042     m24    23   ADNI1    ADNI1  2007-11-30  LMCI  72.8
# 74   42  023_S_0042     m36    23   ADNI1    ADNI1  2008-12-05  LMCI  72.8
# 75   42  023_S_0042     m48    23   ADNI1    ADNI1  2010-03-18  LMCI  72.8
#
#    PTGENDER        DX
# 5      Male       MCI
# 6      Male       MCI
# 7      Male       MCI
# 8      Male       MCI
# 9      Male       MCI
# 15   Female       MCI
# 16   Female       MCI
# 17   Female       MCI
# 18   Female       MCI
# 19   Female       MCI
# 55     Male       MCI
# 56     Male       MCI
# 68   Female       MCI
# 69     Male       MCI
# 70     Male       MCI
# 71     Male  Dementia
# 72     Male  Dementia
# 73     Male  Dementia
# 74     Male  Dementia
# 75     Male  Dementia

# %%
# OF THESE SUBJECTS, KEEP ONLY INFO OF CONVERTION BY YEAR 3
visitcode_selected = ["bl","m03","m30","m36","m24","m18","m12","m06"]
adnimerge_selected_nadine = adnimerge_MCI_patients4.loc[adnimerge_MCI_patients4["VISCODE"].isin(visitcode_selected)]
#adnimerge_selected_nadine.head(20)
np.count_nonzero(np.unique(adnimerge_selected_nadine["RID"]))
# Out:
# 548

# %%
differ_RID = [x for x in to_include_subjects if x not in MCI_patients_RID4]
differ_RID
# Out:
# [995, 1226]

# %%
#check what difference it gives when using on m36 
#INCLUDE ONLY SUBJECTS WITH VISCODE of m36 available
visitcode_required = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36"]
visitcode_m36 = ["m36"]
MCI_patients_RID5 = np.unique(adnimerge_MCI_patients3[adnimerge_MCI_patients3["VISCODE"].isin(visitcode_m36)]["RID"])
adnimerge_MCI_patients5 = adnimerge_MCI_patients3.loc[adnimerge_MCI_patients3["RID"].isin(MCI_patients_RID5)]
adnimerge_MCI_patients5.head(50)
np.count_nonzero(np.unique(adnimerge_MCI_patients5["RID"]))
# Out:
# 523

# %%
# OF THESE SUBJECTS, KEEP ONLY INFO OF CONVERSION BY YEAR 3
visitcode_selected = ["bl","m03","m30","m36","m24","m18","m12","m06"]
adnimerge_selected_nadine = adnimerge_MCI_patients5[adnimerge_MCI_patients5["VISCODE"].isin(visitcode_selected)]
adnimerge_selected_nadine.head(20)
#np.count_nonzero(np.unique(adnimerge_selected_nadine["RID"]))
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# 56   33  035_S_0033     m36    35   ADNI1    ADNI1  2009-01-09  LMCI  83.3
# 68   41  007_S_0041     m06     7   ADNI1    ADNI1  2006-05-15  LMCI  70.9
# 69   42  023_S_0042      bl    23   ADNI1    ADNI1  2005-11-10  LMCI  72.8
# 70   42  023_S_0042     m06    23   ADNI1    ADNI1  2006-05-02  LMCI  72.8
# 71   42  023_S_0042     m12    23   ADNI1    ADNI1  2006-11-09  LMCI  72.8
# 72   42  023_S_0042     m18    23   ADNI1    ADNI1  2007-05-10  LMCI  72.8
# 73   42  023_S_0042     m24    23   ADNI1    ADNI1  2007-11-30  LMCI  72.8
# 74   42  023_S_0042     m36    23   ADNI1    ADNI1  2008-12-05  LMCI  72.8
# 90   50  123_S_0050     m18   123   ADNI1    ADNI1  2007-06-20  LMCI  77.6
#
#    PTGENDER        DX
# 5      Male       MCI
# 6      Male       MCI
# 7      Male       MCI
# 8      Male       MCI
# 9      Male       MCI
# 15   Female       MCI
# 16   Female       MCI
# 17   Female       MCI
# 18   Female       MCI
# 19   Female       MCI
# 55     Male       MCI
# 56     Male       MCI
# 68   Female       MCI
# 69     Male       MCI
# 70     Male       MCI
# 71     Male  Dementia
# 72     Male  Dementia
# 73     Male  Dementia
# 74     Male  Dementia
# 90     Male  Dementia

# %%
#adding converter_at_3years variable
#not sure how to construct the for loops for this, so first re-run the code from Massi below

visitcode_selected2 = ["m03","m30","m36","m24","m18","m12","m06"]

adnimerge_selected_massi["conversion"] = "no"

for 
if adnimerge_selected_massi["VISCODE"].isin(visitcode_selected2) & adnimerge_selected_massi["DX"] == "Dementia"
        adnimerge_selected_massi["conversion"] = "yes"

        
        
adnimerge_selected_massi.head()
# Out:
#   File "<ipython-input-44-bc708f895dba>", line 8
#     for
#         ^
# SyntaxError: invalid syntax

# %%
#code from Massi
#RESHAPE ADNIMERGE AND ADD CONVERTION VARIABLE AT THE END
tempo = adnimerge_selected_massi.copy()
tempo.index = np.array(range(tempo.shape[0]))
adnimerge_selected_massi = adnimerge_selected_massi[adnimerge_selected_massi['VISCODE'] == "bl"]
adnimerge_selected_massi.index = np.array(range(adnimerge_selected_massi.shape[0]))

adnimerge_selected_massi["CONVERSION_AT_3Y"] = "NO"

for i in range(adnimerge_selected_massi.shape[0]):
    if "Dementia" in np.array(tempo["DX"].loc[tempo["RID"] == adnimerge_selected_massi["RID"].iloc[i]]):
        adnimerge_selected_massi["CONVERSION_AT_3Y"].iloc[i] = "YES"
        
adnimerge_selected_massi.head(50)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 
# 32  231  021_S_0231      bl    21   ADNI1    ADNI1  2006-03-16  LMCI  60.3
# 33  249  007_S_0249      bl     7   ADNI1    ADNI1  2006-03-14  LMCI  72.0
# 34  256  027_S_0256      bl    27   ADNI1    ADNI1  2006-04-05  LMCI  70.1
# 35  258  128_S_0258      bl   128   ADNI1    ADNI1  2006-05-02  LMCI  71.3
# 36  269  098_S_0269      bl    98   ADNI1    ADNI1  2006-04-12  LMCI  67.1
# 37  273  021_S_0273      bl    21   ADNI1    ADNI1  2006-04-05  LMCI  62.8
# 38  276  021_S_0276      bl    21   ADNI1    ADNI1  2006-03-29  LMCI  70.9
# 39  285  130_S_0285      bl   130   ADNI1    ADNI1  2006-04-03  LMCI  65.6
# 40  289  130_S_0289      bl   130   ADNI1    ADNI1  2006-03-31  LMCI  67.7
# 41  291  099_S_0291      bl    99   ADNI1    ADNI1  2006-03-24  LMCI  79.4
# 42  292  035_S_0292      bl    35   ADNI1    ADNI1  2006-04-12  LMCI  76.4
# 43  296  100_S_0296      bl   100   ADNI1    ADNI1  2006-04-25  LMCI  79.1
# 44  307  027_S_0307      bl    27   ADNI1    ADNI1  2006-04-28  LMCI  78.5
# 45  314  041_S_0314      bl    41   ADNI1    ADNI1  2006-04-20  LMCI  72.1
# 46  324  005_S_0324      bl     5   ADNI1    ADNI1  2006-04-21  LMCI  75.3
# 47  331  023_S_0331      bl    23   ADNI1    ADNI1  2006-04-06  LMCI  64.6
# 48  336  067_S_0336      bl    67   ADNI1    ADNI1  2006-06-01  LMCI  76.1
# 49  344  007_S_0344      bl     7   ADNI1    ADNI1  2006-04-19  LMCI  78.8
#
#    PTGENDER   DX CONVERSION_AT_3Y
# 0      Male  MCI               NO
# 1    Female  MCI               NO
# 2      Male  MCI              YES
# 3      Male  MCI               NO
# 4    Female  MCI              YES
# 5      Male  MCI              YES
# 6      Male  MCI              YES
# 7      Male  MCI               NO
# 8    Female  MCI              YES
# 9      Male  MCI              YES
# 10   Female  MCI               NO
# 11     Male  MCI              YES
# 12     Male  MCI               NO
# 13     Male  MCI               NO
# 14   Female  MCI              YES
# 15   Female  MCI              YES
# 16     Male  MCI               NO
# 17     Male  MCI              YES
# 18     Male  MCI               NO
# 19     Male  MCI               NO
# 20     Male  MCI               NO
# 21     Male  MCI              YES
# 22     Male  MCI               NO
# 23     Male  MCI               NO
# 24     Male  MCI              YES
# 25     Male  MCI               NO
# 26     Male  MCI              YES
# 27     Male  MCI               NO
# 28   Female  MCI              YES
# 29     Male  MCI              YES
# 30   Female  MCI               NO
# 31   Female  MCI              YES
# 32     Male  MCI              YES
# 33   Female  MCI              YES
# 34     Male  MCI              YES
# 35   Female  MCI              YES
# 36     Male  MCI              YES
# 37     Male  MCI               NO
# 38     Male  MCI               NO
# 39     Male  MCI               NO
# 40     Male  MCI              YES
# 41     Male  MCI               NO
# 42     Male  MCI               NO
# 43     Male  MCI               NO
# 44     Male  MCI               NO
# 45     Male  MCI              YES
# 46   Female  MCI               NO
# 47   Female  MCI              YES
# 48     Male  MCI              YES
# 49     Male  MCI              YES
