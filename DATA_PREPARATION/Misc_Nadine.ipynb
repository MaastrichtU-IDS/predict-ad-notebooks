# %% [markdown]
# # PredictAD: miscellanious Nadine

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from collections import Counter

# %%
ADNIMERGE = pd.read_csv("../../DATA_15_12_2017/Study_Info/ADNIMERGE.csv")
ADNIMERGE.head(10)
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
# 5    4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6    4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7    4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8    4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9    4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
#
#   PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0     Male          ...               NaN     NaN  1.36926    NaN      NaN
# ...

# %%
ADNIMERGE[ADNIMERGE['RID'] == 42]['DX']
# Out:
# 69            MCI
# 70            MCI
# 71       Dementia
# 72       Dementia
# 73       Dementia
# 74       Dementia
# 75       Dementia
# 5181          NaN
# 5182          NaN
# 5183          NaN
# 11141         NaN
# 11142    Dementia
# 11143         NaN
# 11144    Dementia
# 11145         NaN
# 11146    Dementia
# 11147         NaN
# 11148    Dementia
# Name: DX, dtype: object

# %%
ADNIMERGE[ADNIMERGE['RID'] == 42]['DX']
# Out:
# 69            MCI
# 70            MCI
# 71       Dementia
# 72       Dementia
# 73       Dementia
# 74       Dementia
# 75       Dementia
# 5181          NaN
# 5182          NaN
# 5183          NaN
# 11141         NaN
# 11142    Dementia
# 11143         NaN
# 11144    Dementia
# 11145         NaN
# 11146    Dementia
# 11147         NaN
# 11148    Dementia
# Name: DX, dtype: object

# %%
ADNIMERGE[ADNIMERGE['RID'] == 51]['DX']
# Out:
# 91            MCI
# 92            MCI
# 93            MCI
# 94            MCI
# 95            MCI
# 96            MCI
# 5213          NaN
# 11129    Dementia
# 11130    Dementia
# 11131    Dementia
# 11132    Dementia
# 11133         NaN
# 11134    Dementia
# Name: DX, dtype: object

# %%
ADNIMERGE[ADNIMERGE['RID'] == 51]['DX_bl']
# Out:
# 91       LMCI
# 92       LMCI
# 93       LMCI
# 94       LMCI
# 95       LMCI
# 96       LMCI
# 5213     LMCI
# 11129    LMCI
# 11130    LMCI
# 11131    LMCI
# 11132    LMCI
# 11133    LMCI
# 11134    LMCI
# Name: DX_bl, dtype: object

# %%
ADNIMERGE_DX_MCI = ADNIMERGE[ADNIMERGE['DX'].isin(['MCI'])]
ADNIMERGE_DX_MCI.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# ...

# %%
ADNIMERGE_DX_bl_ELMCI = ADNIMERGE[ADNIMERGE['DX_bl'].isin(['EMCI', 'LMCI'])]
ADNIMERGE_DX_bl_ELMCI.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# ...

# %%
ADNIMERGE_DX_bl_ELMCI = ADNIMERGE[ADNIMERGE['DX_bl'].isin(['EMCI', 'LMCI'])]
ADNIMERGE_DX_bl_ELMCI.head(20)
ADNIMERGE = ADNIMERGE_DX_bl_ELMCI 

ADNIMERGE_3year = ADNIMERGE[ADNIMERGE['VISCODE'].isin(["bl","m03","m30","m36","m24","m18","m12","m06"])]
ADNIMERGE_3year.head(20)
ADNIMERGE = ADNIMERGE_3year

ADNIMERGE.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# ...

# %%
#tempo = ADNIMERGE.copy()
#tempo.index = np.array(range(tempo.shape[0]))
ADNIMERGE = ADNIMERGE[ADNIMERGE['VISCODE'].isin((["sc","bl","v03"]))]
ADNIMERGE.index = np.array(range(ADNIMERGE.shape[0]))
ADNIMERGE.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 1     6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 2    38  067_S_0038      bl    67   ADNI1    ADNI1  2005-12-15  LMCI  76.8
# 3    42  023_S_0042      bl    23   ADNI1    ADNI1  2005-11-10  LMCI  72.8
# 4    45  067_S_0045      bl    67   ADNI1    ADNI1  2006-01-11  LMCI  85.9
# 5    51  099_S_0051      bl    99   ADNI1    ADNI1  2005-12-08  LMCI  66.5
# 6    54  099_S_0054      bl    99   ADNI1    ADNI1  2005-12-16  LMCI  81.0
# 7    57  018_S_0057      bl    18   ADNI1    ADNI1  2006-01-06  LMCI  77.3
# 8    60  099_S_0060      bl    99   ADNI1    ADNI1  2006-01-09  LMCI  70.0
# 9    77  067_S_0077      bl    67   ADNI1    ADNI1  2006-02-08  LMCI  79.7
# 10   80  018_S_0080      bl    18   ADNI1    ADNI1  2006-01-13  LMCI  85.0
# ...

# %%
########## Import ADNIMERGE FILE for baseline diagnosis and convertion at 3 years

#ADNIMERGE_DX_bl_ELMCI = ADNIMERGE[ADNIMERGE['DX_bl'].isin(['EMCI', 'LMCI'])]
#ADNIMERGE_DX_bl_ELMCI.head(20)

# INCLUDE ONLY MCI
to_include_mci = np.unique(np.array(ADNIMERGE[ADNIMERGE["DX_bl"].isin(["EMCI","LMCI"])]['RID']))
to_include_mci

ADNIMERGE = ADNIMERGE[ADNIMERGE["RID"].isin(to_include_mci)]
ADNIMERGE.head(20)

# INCLUDE ONLY SUBJECTS WITH INFO OF CONVERTION AT LEAST YEAR 3
to_include_time = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36"]
to_include_subjects = np.unique(np.array(ADNIMERGE[ADNIMERGE["VISCODE"].isin(to_include_time)]['RID']))
to_include_subjects

ADNIMERGE = ADNIMERGE[ADNIMERGE["RID"].isin(to_include_subjects)]
ADNIMERGE.head(20)

# OF THESE SUBJECTS, KEEP ONLY INFO OF CONVERTION BY YEAR 3
to_include_time_2 = ["bl","m03","m30","m36","m24","m18","m12","m06"]
ADNIMERGE = ADNIMERGE.loc[ADNIMERGE["VISCODE"].isin(to_include_time_2)]
ADNIMERGE.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# ...

# %%
ADNIMERGE[ADNIMERGE['RID'] == 33]['VISCODE']
# Out:
# 566    bl
# Name: VISCODE, dtype: object

# %%
times = ["m114","m126","m144","m102","m132","m120","m108","m90","m96","m84","m78","m66","m54","m42","m72","m60","m48","m36","bl","m03","m30","m24","m18","m12","m06"]
ADNIMERGE3 = ADNIMERGE[ADNIMERGE['VISCODE'].isin(times)]
ADNIMERGE3 = ADNIMERGE[ADNIMERGE['VISCODE'].isin(["bl","m03","m30","m36","m24","m18","m12","m06"])]
ADNIMERGE3.head(20)
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 6     4  022_S_0004     m06    22   ADNI1    ADNI1  2006-05-02  LMCI  67.5
# 7     4  022_S_0004     m12    22   ADNI1    ADNI1  2006-11-14  LMCI  67.5
# 8     4  022_S_0004     m18    22   ADNI1    ADNI1  2007-05-14  LMCI  67.5
# 9     4  022_S_0004     m36    22   ADNI1    ADNI1  2008-11-18  LMCI  67.5
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
# 16    6  100_S_0006     m06   100   ADNI1    ADNI1  2006-06-01  LMCI  80.4
# 17    6  100_S_0006     m12   100   ADNI1    ADNI1  2006-11-20  LMCI  80.4
# 18    6  100_S_0006     m18   100   ADNI1    ADNI1  2007-05-15  LMCI  80.4
# 19    6  100_S_0006     m36   100   ADNI1    ADNI1  2008-12-08  LMCI  80.4
# 55   33  035_S_0033     m12    35   ADNI1    ADNI1  2006-12-14  LMCI  83.3
# ...

# %%
# RESHAPE ADNIMERGE AND ADD CONVERTION VARIABLE AT THE END
tempo = ADNIMERGE.copy()
tempo.index = np.array(range(tempo.shape[0]))
ADNIMERGE = ADNIMERGE.loc[ADNIMERGE['VISCODE'].isin((["sc","bl","v03"]))]
ADNIMERGE.index = np.array(range(ADNIMERGE.shape[0]))

ADNIMERGE["CONVERSION_AT_3Y"] = "NO"

for i in range(ADNIMERGE.shape[0]):
    if "Dementia" in np.array(tempo["DX"].loc[tempo["RID"] == ADNIMERGE["RID"].iloc[i]]):
        ADNIMERGE["CONVERSION_AT_3Y"].iloc[i] = "YES"
# Out:
# /Users/nadinerouleaux/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
adnimerge_baseline = adnimerge[adnimerge['VISCODE'] == 'bl']
adnimerge_baseline.head()
# Out:
#     RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0     2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1     3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 5     4  022_S_0004      bl    22   ADNI1    ADNI1  2005-11-08  LMCI  67.5
# 10    5  011_S_0005      bl    11   ADNI1    ADNI1  2005-09-07    CN  73.7
# 15    6  100_S_0006      bl   100   ADNI1    ADNI1  2005-11-29  LMCI  80.4
#
#    PTGENDER          ...            TAU_bl PTAU_bl   FDG_bl PIB_bl  AV45_bl  \
# 0      Male          ...               NaN     NaN  1.36926    NaN      NaN
# 1      Male          ...             239.7   22.83  1.09079    NaN      NaN
# 5      Male          ...             153.1   13.29      NaN    NaN      NaN
# 10     Male          ...             337.0   33.43  1.29799    NaN      NaN
# 15   Female          ...               NaN     NaN      NaN    NaN      NaN
#
#     Years_bl  Month_bl  Month  M           update_stamp
# ...

# %%
Counter(adnimerge_baseline['DX'])
# Out:
# Counter({'CN': 453, 'Dementia': 335, 'MCI': 791, nan: 20})

# %%
plt.figure(figsize=(15,6))

sns.distplot(adnimerge_baseline[adnimerge_baseline['DX']=='CN']['MMSE'], hist = False)#(adnimerge_baseline['MMSE'])
sns.distplot(adnimerge_baseline[adnimerge_baseline['DX']=='Dementia']['MMSE'], hist = False)
sns.distplot(adnimerge_baseline[adnimerge_baseline['DX']=='MCI']['MMSE'], hist = False)

# %%
np.array(adnimerge_baseline[adnimerge_baseline['DX']=='Dementia'][variable]).mean()
